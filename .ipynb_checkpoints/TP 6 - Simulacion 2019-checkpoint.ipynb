# %%
# import the SimPy package 
#from simpy import initialize
#from SimPy.Simulation import *
import simpy
import random
import collections

# %% [markdown]
#
#
#
#
#
#        .

# %%
def distribucion_llegada(env,puestos,cont,n):
    while True:
    #for i in range(n):
        cont["NT"] += 1
        r = random.random()
        #print("Distribucion de generacion de tipo de cliente: %5.2f"%r)
        if r <= cont["PE"]:
            ce = Customer(name = "clienteE%02d"%cont["NT"])
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA EMERGENCIA - llegue con un IA: %5.2f"%(env.now,ce.name,ia))
            colas(puestos)
            env.process(ce.llamada_emergencia(env,puestos,cont))
        else: 
            cc = Customer(name = "clienteC%02d"%cont["NT"])
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA COMERCIAL - llegue con un IA: %5.2f"%(env.now,cc.name,ia))
            colas(puestos)
            env.process(cc.llamada_comercial(env,puestos,cont))

# %%
class Customer():
    """Evento llegadas/llamadas de los clientes"""
    def __init__(self,name):
        self.name = name
        
    def llamada_emergencia(self,env,puestos,cont):
        arrive = env.now
        # Pido uso de los dos puestos, y me dan el primero que se libere
        emergencia, comercial = puestos[1].request(priority=0), puestos[0].request(priority=0)
        atendido = yield emergencia | comercial 
        #assert atendido == {emergencia}
        
        # Me atendieron por puestos comerciales?
        if comercial in atendido:
            cont["multitasking"]+=1
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de emergencia"%(env.now,self.name))
            
        else:
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
            
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de emergencia"%(env.now,self.name))
            
            
    def llamada_comercial(self,env,puestos,cont):
        arrive = env.now
        with puestos[0].request(priority=1) as request:
            yield request
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA COMERCIAL - Me atendieron despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto comercial"%(env.now,self.name))

# %%
def colas(p):
    print ("Atendiendo:[c:%1d, e:%1d]"%(p[0].count,p[1].count))
    print ("En cola:[c:%1d, e:%1d]"%(len(p[0].queue),len(p[1].queue)))

# %%
def generar_TA(cont):
    #(a=5,b=615)
    a=5
    b=615
    ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
    
    while ta<a: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta>b:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta>b:
                continue
            else:
                break
        
    while ta>b: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta<a:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta<a:
                continue
            else:
                break
            
    return ta

# %% [markdown]
# Condiciones Iniciales

# %%
# Experimental data
NT = 0
maxTime = 14400 #segundos
maxClient = 10000
#random.seed(RANDOM_SEED)
PE = 0.12 #Porcentaje Emergencia
PC = 0.88 #Porcentaje Comercial
NEC = 0 #Cantidad de gente que espero en cola menor a 40 segundos
PEC = 0.0 #Porcentaje de espera en cola menor a 40 segundos

# TA - distribucion normal
mu = 267.64 
sigma = 297.40

# IA - uniforme
IAMin = 1
IAMax = 60

# Contadores
ci = {"multitasking":0,
     "mu":mu,
     "sigma":sigma,
     "min":IAMin,
     "max":IAMax,
     "PE":PE,
     "PC":PC,
     "emer":0,
     "com":0,
     "NEC":NEC,
     "NT":NT}

# %%
# Puestos de atencion - variables de control
print('Ingrese cantidad de puestos comerciales')
cantCom = int(input())
ci["com"] = cantCom
print('Ingrese cantidad de puestos de emergencia')
cantEmer = int(input())
ci["emer"] = cantEmer
# Out:
# Ingrese cantidad de puestos comerciales
# 60
# Ingrese cantidad de puestos de emergencia
# 20

# %% [markdown]
# Modelo de Simulacion

# %%
env = simpy.Environment()
puestos = [simpy.PriorityResource(env,capacity=cantCom),
           simpy.PriorityResource(env,capacity=cantEmer)] # menor el numero priority, mayor es la prioridad
           
env.process(distribucion_llegada(env,puestos,ci,n=maxClient))
env.run(until=maxTime)
# Out:
# T=13.22 clienteC489: COLA COMERCIAL - llegue con un IA: 13.22
# Atendiendo:[c:0, e:0]
# En cola:[c:0, e:0]
# T=13.22, clienteC489: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC489: 205.77
# T=31.98 clienteC490: COLA COMERCIAL - llegue con un IA: 18.76
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# T=31.98, clienteC490: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC490: 60.19
# T=45.02 clienteC491: COLA COMERCIAL - llegue con un IA: 13.04
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# T=45.02, clienteC491: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC491: 370.54
# T=61.09 clienteC492: COLA COMERCIAL - llegue con un IA: 16.07
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# T=61.09, clienteC492: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC492: 284.96
# T=92.17, clienteC490: Sali de un puesto comercial
# T=98.06 clienteC493: COLA COMERCIAL - llegue con un IA: 36.97
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# T=98.06, clienteC493: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC493: 305.64
# T=122.73 clienteC494: COLA COMERCIAL - llegue con un IA: 24.67
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# T=122.73, clienteC494: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC494: 82.31
# T=160.67 clienteE495: COLA EMERGENCIA - llegue con un IA: 37.94
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# T=160.67, clienteE495: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE495: 567.52
# T=187.79 clienteC496: COLA COMERCIAL - llegue con un IA: 27.12
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# T=187.79, clienteC496: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC496: 87.68
# T=205.04, clienteC494: Sali de un puesto comercial
# T=218.99, clienteC489: Sali de un puesto comercial
# T=219.09 clienteC497: COLA COMERCIAL - llegue con un IA: 31.30
# Atendiendo:[c:5, e:1]
# En cola:[c:0, e:0]
# T=219.09, clienteC497: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC497: 504.63
# T=240.51 clienteC498: COLA COMERCIAL - llegue con un IA: 21.42
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# T=240.51, clienteC498: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC498: 581.94
# T=264.49 clienteC499: COLA COMERCIAL - llegue con un IA: 23.97
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=264.49, clienteC499: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC499: 128.53
# T=275.47, clienteC496: Sali de un puesto comercial
# T=277.20 clienteC500: COLA COMERCIAL - llegue con un IA: 12.71
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=277.20, clienteC500: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC500: 295.50
# T=283.38 clienteC501: COLA COMERCIAL - llegue con un IA:  6.18
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=283.38, clienteC501: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC501: 79.70
# T=290.08 clienteC502: COLA COMERCIAL - llegue con un IA:  6.70
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# T=290.08, clienteC502: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC502: 258.69
# T=331.93 clienteC503: COLA COMERCIAL - llegue con un IA: 41.85
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# T=331.93, clienteC503: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC503: 402.81
# T=346.05, clienteC492: Sali de un puesto comercial
# T=352.24 clienteC504: COLA COMERCIAL - llegue con un IA: 20.31
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# T=352.24, clienteC504: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC504: 299.59
# T=361.90 clienteC505: COLA COMERCIAL - llegue con un IA:  9.66
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# T=361.90, clienteC505: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC505: 547.18
# T=363.08, clienteC501: Sali de un puesto comercial
# T=371.33 clienteC506: COLA COMERCIAL - llegue con un IA:  9.43
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# T=371.33, clienteC506: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC506: 25.47
# T=393.02, clienteC499: Sali de un puesto comercial
# T=396.81, clienteC506: Sali de un puesto comercial
# T=403.70, clienteC493: Sali de un puesto comercial
# T=404.89 clienteC507: COLA COMERCIAL - llegue con un IA: 33.55
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# T=404.89, clienteC507: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC507: 381.02
# T=415.56, clienteC491: Sali de un puesto comercial
# T=444.48 clienteC508: COLA COMERCIAL - llegue con un IA: 39.60
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# T=444.48, clienteC508: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC508: 108.19
# T=465.38 clienteC509: COLA COMERCIAL - llegue con un IA: 20.90
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# T=465.38, clienteC509: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC509: 122.70
# T=523.51 clienteC510: COLA COMERCIAL - llegue con un IA: 58.13
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# T=523.51, clienteC510: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC510: 410.63
# T=548.77, clienteC502: Sali de un puesto comercial
# T=552.68, clienteC508: Sali de un puesto comercial
# T=557.83 clienteE511: COLA EMERGENCIA - llegue con un IA: 34.32
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# T=557.83, clienteE511: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE511: 434.68
# T=572.70, clienteC500: Sali de un puesto comercial
# T=588.09, clienteC509: Sali de un puesto comercial
# T=593.18 clienteC512: COLA COMERCIAL - llegue con un IA: 35.35
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# T=593.18, clienteC512: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC512: 275.45
# T=600.11 clienteC513: COLA COMERCIAL - llegue con un IA:  6.93
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# T=600.11, clienteC513: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC513: 380.02
# T=651.83, clienteC504: Sali de un puesto comercial
# T=656.73 clienteC514: COLA COMERCIAL - llegue con un IA: 56.62
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# T=656.73, clienteC514: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC514: 239.36
# T=674.62 clienteC515: COLA COMERCIAL - llegue con un IA: 17.89
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# T=674.62, clienteC515: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC515: 162.45
# T=685.50 clienteC516: COLA COMERCIAL - llegue con un IA: 10.88
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# T=685.50, clienteC516: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC516: 239.44
# T=721.32 clienteC517: COLA COMERCIAL - llegue con un IA: 35.83
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# T=721.32, clienteC517: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC517: 429.84
# T=723.72, clienteC497: Sali de un puesto comercial
# T=728.20, clienteE495: Sali de un puesto de emergencia
# T=733.91 clienteC518: COLA COMERCIAL - llegue con un IA: 12.58
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# T=733.91, clienteC518: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC518: 61.99
# T=734.74, clienteC503: Sali de un puesto comercial
# T=785.91, clienteC507: Sali de un puesto comercial
# T=787.38 clienteC519: COLA COMERCIAL - llegue con un IA: 53.48
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# T=787.38, clienteC519: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC519: 122.60
# T=795.89, clienteC518: Sali de un puesto comercial
# T=822.45, clienteC498: Sali de un puesto comercial
# T=833.75 clienteE520: COLA EMERGENCIA - llegue con un IA: 46.37
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# T=833.75, clienteE520: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE520: 308.20
# T=837.07, clienteC515: Sali de un puesto comercial
# T=856.64 clienteC521: COLA COMERCIAL - llegue con un IA: 22.89
# Atendiendo:[c:11, e:3]
# En cola:[c:0, e:0]
# T=856.64, clienteC521: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC521: 387.06
# T=868.64, clienteC512: Sali de un puesto comercial
# T=896.09, clienteC514: Sali de un puesto comercial
# T=909.08, clienteC505: Sali de un puesto comercial
# T=909.69 clienteC522: COLA COMERCIAL - llegue con un IA: 53.05
# Atendiendo:[c:9, e:3]
# En cola:[c:0, e:0]
# T=909.69, clienteC522: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC522: 40.14
# T=909.98, clienteC519: Sali de un puesto comercial
# T=924.94, clienteC516: Sali de un puesto comercial
# T=934.14, clienteC510: Sali de un puesto comercial
# T=949.84, clienteC522: Sali de un puesto comercial
# T=968.15 clienteC523: COLA COMERCIAL - llegue con un IA: 58.45
# Atendiendo:[c:6, e:3]
# En cola:[c:0, e:0]
# T=968.15, clienteC523: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:7, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC523: 117.72
# T=980.14, clienteC513: Sali de un puesto comercial
# T=992.52, clienteE511: Sali de un puesto de emergencia
# T=996.81 clienteE524: COLA EMERGENCIA - llegue con un IA: 28.66
# Atendiendo:[c:6, e:3]
# En cola:[c:0, e:0]
# T=996.81, clienteE524: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:7, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE524: 311.52
# T=1022.04 clienteC525: COLA COMERCIAL - llegue con un IA: 25.23
# Atendiendo:[c:7, e:4]
# En cola:[c:0, e:0]
# T=1022.04, clienteC525: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC525: 480.05
# T=1023.17 clienteC526: COLA COMERCIAL - llegue con un IA:  1.13
# Atendiendo:[c:8, e:4]
# En cola:[c:0, e:0]
# T=1023.17, clienteC526: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC526: 130.97
# T=1029.67 clienteC527: COLA COMERCIAL - llegue con un IA:  6.50
# Atendiendo:[c:9, e:4]
# En cola:[c:0, e:0]
# T=1029.67, clienteC527: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC527: 181.77
# T=1058.51 clienteC528: COLA COMERCIAL - llegue con un IA: 28.85
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1058.51, clienteC528: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC528: 176.67
# T=1080.19 clienteC529: COLA COMERCIAL - llegue con un IA: 21.68
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1080.19, clienteC529: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC529: 311.29
# T=1085.86, clienteC523: Sali de un puesto comercial
# T=1133.22 clienteC530: COLA COMERCIAL - llegue con un IA: 53.03
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1133.22, clienteC530: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC530: 13.42
# T=1141.95, clienteE520: Sali de un puesto de emergencia
# T=1144.12 clienteC531: COLA COMERCIAL - llegue con un IA: 10.90
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# T=1144.12, clienteC531: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC531: 274.36
# T=1146.63, clienteC530: Sali de un puesto comercial
# T=1151.17, clienteC517: Sali de un puesto comercial
# T=1154.14, clienteC526: Sali de un puesto comercial
# T=1163.36 clienteC532: COLA COMERCIAL - llegue con un IA: 19.24
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1163.36, clienteC532: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC532: 154.93
# T=1204.52 clienteC533: COLA COMERCIAL - llegue con un IA: 41.17
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1204.52, clienteC533: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC533: 85.96
# T=1211.44, clienteC527: Sali de un puesto comercial
# T=1235.18, clienteC528: Sali de un puesto comercial
# T=1243.70, clienteC521: Sali de un puesto comercial
# T=1261.39 clienteC534: COLA COMERCIAL - llegue con un IA: 56.86
# Atendiendo:[c:9, e:4]
# En cola:[c:0, e:0]
# T=1261.39, clienteC534: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC534: 197.56
# T=1263.58 clienteC535: COLA COMERCIAL - llegue con un IA:  2.19
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1263.58, clienteC535: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC535: 134.55
# T=1290.48, clienteC533: Sali de un puesto comercial
# T=1295.44 clienteC536: COLA COMERCIAL - llegue con un IA: 31.86
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1295.44, clienteC536: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC536: 517.55
# T=1308.33, clienteE524: Sali de un puesto de emergencia
# T=1315.62 clienteC537: COLA COMERCIAL - llegue con un IA: 20.17
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1315.62, clienteC537: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC537: 287.59
# T=1318.28, clienteC532: Sali de un puesto comercial
# T=1354.61 clienteC538: COLA COMERCIAL - llegue con un IA: 38.99
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1354.61, clienteC538: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC538: 360.38
# T=1377.03 clienteC539: COLA COMERCIAL - llegue con un IA: 22.42
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# T=1377.03, clienteC539: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC539: 496.11
# T=1391.48, clienteC529: Sali de un puesto comercial
# T=1398.14, clienteC535: Sali de un puesto comercial
# T=1418.48, clienteC531: Sali de un puesto comercial
# T=1434.54 clienteC540: COLA COMERCIAL - llegue con un IA: 57.51
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1434.54, clienteC540: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC540: 38.35
# T=1448.98 clienteC541: COLA COMERCIAL - llegue con un IA: 14.44
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1448.98, clienteC541: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC541: 218.19
# T=1458.95, clienteC534: Sali de un puesto comercial
# T=1471.49 clienteE542: COLA EMERGENCIA - llegue con un IA: 22.51
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1471.49, clienteE542: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE542: 521.47
# T=1472.90, clienteC540: Sali de un puesto comercial
# T=1478.53 clienteE543: COLA EMERGENCIA - llegue con un IA:  7.04
# Atendiendo:[c:11, e:5]
# En cola:[c:0, e:0]
# T=1478.53, clienteE543: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE543: 574.60
# T=1496.10 clienteC544: COLA COMERCIAL - llegue con un IA: 17.57
# Atendiendo:[c:12, e:6]
# En cola:[c:0, e:0]
# T=1496.10, clienteC544: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC544: 106.79
# T=1502.09, clienteC525: Sali de un puesto comercial
# T=1542.12 clienteE545: COLA EMERGENCIA - llegue con un IA: 46.02
# Atendiendo:[c:12, e:6]
# En cola:[c:0, e:0]
# T=1542.12, clienteE545: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:13, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE545: 133.41
# T=1570.76 clienteC546: COLA COMERCIAL - llegue con un IA: 28.64
# Atendiendo:[c:13, e:7]
# En cola:[c:0, e:0]
# T=1570.76, clienteC546: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC546: 102.36
# T=1602.89, clienteC544: Sali de un puesto comercial
# T=1603.21, clienteC537: Sali de un puesto comercial
# T=1616.71 clienteE547: COLA EMERGENCIA - llegue con un IA: 45.95
# Atendiendo:[c:12, e:7]
# En cola:[c:0, e:0]
# T=1616.71, clienteE547: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE547: 14.20
# T=1623.13 clienteC548: COLA COMERCIAL - llegue con un IA:  6.41
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# T=1623.13, clienteC548: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC548: 232.14
# T=1630.91, clienteE547: Sali de un puesto de emergencia
# T=1667.17, clienteC541: Sali de un puesto comercial
# T=1673.11, clienteC546: Sali de un puesto comercial
# T=1675.53, clienteE545: Sali de un puesto de emergencia
# T=1676.69 clienteC549: COLA COMERCIAL - llegue con un IA: 53.57
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# T=1676.69, clienteC549: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC549: 257.44
# T=1714.99, clienteC538: Sali de un puesto comercial
# T=1728.86 clienteC550: COLA COMERCIAL - llegue con un IA: 52.17
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# T=1728.86, clienteC550: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC550: 313.20
# T=1756.32 clienteC551: COLA COMERCIAL - llegue con un IA: 27.46
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# T=1756.32, clienteC551: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC551: 74.49
# T=1758.10 clienteE552: COLA EMERGENCIA - llegue con un IA:  1.78
# Atendiendo:[c:14, e:8]
# En cola:[c:0, e:0]
# T=1758.10, clienteE552: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:15, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE552: 569.35
# T=1777.52 clienteC553: COLA COMERCIAL - llegue con un IA: 19.42
# Atendiendo:[c:15, e:9]
# En cola:[c:0, e:0]
# T=1777.52, clienteC553: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC553: 127.08
# T=1783.56 clienteC554: COLA COMERCIAL - llegue con un IA:  6.04
# Atendiendo:[c:16, e:9]
# En cola:[c:0, e:0]
# T=1783.56, clienteC554: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC554: 116.94
# T=1812.99, clienteC536: Sali de un puesto comercial
# T=1822.42 clienteC555: COLA COMERCIAL - llegue con un IA: 38.85
# Atendiendo:[c:16, e:9]
# En cola:[c:0, e:0]
# T=1822.42, clienteC555: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC555: 276.19
# T=1830.81, clienteC551: Sali de un puesto comercial
# T=1855.26, clienteC548: Sali de un puesto comercial
# T=1867.18 clienteE556: COLA EMERGENCIA - llegue con un IA: 44.77
# Atendiendo:[c:15, e:9]
# En cola:[c:0, e:0]
# T=1867.18, clienteE556: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE556: 309.96
# T=1873.14, clienteC539: Sali de un puesto comercial
# T=1893.63 clienteE557: COLA EMERGENCIA - llegue con un IA: 26.45
# Atendiendo:[c:15, e:10]
# En cola:[c:0, e:0]
# T=1893.63, clienteE557: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:16, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE557: 111.14
# T=1900.51, clienteC554: Sali de un puesto comercial
# T=1904.60, clienteC553: Sali de un puesto comercial
# T=1920.17 clienteC558: COLA COMERCIAL - llegue con un IA: 26.54
# Atendiendo:[c:14, e:11]
# En cola:[c:0, e:0]
# T=1920.17, clienteC558: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC558: 449.70
# T=1934.13, clienteC549: Sali de un puesto comercial
# T=1959.60 clienteC559: COLA COMERCIAL - llegue con un IA: 39.42
# Atendiendo:[c:14, e:11]
# En cola:[c:0, e:0]
# T=1959.60, clienteC559: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC559: 171.58
# T=1992.96, clienteE542: Sali de un puesto de emergencia
# T=2004.77, clienteE557: Sali de un puesto de emergencia
# T=2012.31 clienteE560: COLA EMERGENCIA - llegue con un IA: 52.72
# Atendiendo:[c:15, e:11]
# En cola:[c:0, e:0]
# T=2012.31, clienteE560: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:16, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE560: 197.42
# T=2042.07, clienteC550: Sali de un puesto comercial
# T=2046.67 clienteC561: COLA COMERCIAL - llegue con un IA: 34.36
# Atendiendo:[c:15, e:12]
# En cola:[c:0, e:0]
# T=2046.67, clienteC561: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC561: 551.87
# T=2053.13, clienteE543: Sali de un puesto de emergencia
# T=2098.60, clienteC555: Sali de un puesto comercial
# T=2101.74 clienteE562: COLA EMERGENCIA - llegue con un IA: 55.08
# Atendiendo:[c:15, e:12]
# En cola:[c:0, e:0]
# T=2101.74, clienteE562: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:16, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE562: 155.37
# T=2123.21 clienteC563: COLA COMERCIAL - llegue con un IA: 21.47
# Atendiendo:[c:16, e:13]
# En cola:[c:0, e:0]
# T=2123.21, clienteC563: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC563: 152.56
# T=2131.17, clienteC559: Sali de un puesto comercial
# T=2174.07 clienteC564: COLA COMERCIAL - llegue con un IA: 50.86
# Atendiendo:[c:16, e:13]
# En cola:[c:0, e:0]
# T=2174.07, clienteC564: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC564: 553.78
# T=2177.14, clienteE556: Sali de un puesto de emergencia
# T=2209.73, clienteE560: Sali de un puesto de emergencia
# T=2223.35 clienteC565: COLA COMERCIAL - llegue con un IA: 49.28
# Atendiendo:[c:17, e:13]
# En cola:[c:0, e:0]
# T=2223.35, clienteC565: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC565: 85.59
# T=2251.67 clienteC566: COLA COMERCIAL - llegue con un IA: 28.32
# Atendiendo:[c:18, e:13]
# En cola:[c:0, e:0]
# T=2251.67, clienteC566: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC566: 386.84
# T=2257.12, clienteE562: Sali de un puesto de emergencia
# T=2275.57 clienteC567: COLA COMERCIAL - llegue con un IA: 23.90
# Atendiendo:[c:19, e:13]
# En cola:[c:0, e:0]
# T=2275.57, clienteC567: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC567: 527.67
# T=2275.77, clienteC563: Sali de un puesto comercial
# T=2308.94, clienteC565: Sali de un puesto comercial
# T=2309.29 clienteC568: COLA COMERCIAL - llegue con un IA: 33.72
# Atendiendo:[c:18, e:13]
# En cola:[c:0, e:0]
# T=2309.29, clienteC568: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC568: 302.20
# T=2327.46, clienteE552: Sali de un puesto de emergencia
# T=2344.57 clienteC569: COLA COMERCIAL - llegue con un IA: 35.27
# Atendiendo:[c:19, e:13]
# En cola:[c:0, e:0]
# T=2344.57, clienteC569: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC569: 320.42
# T=2356.51 clienteC570: COLA COMERCIAL - llegue con un IA: 11.94
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=2356.51, clienteC570: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC570: 271.51
# T=2366.16 clienteC571: COLA COMERCIAL - llegue con un IA:  9.65
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# T=2366.16, clienteC571: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC571: 342.07
# T=2369.88, clienteC558: Sali de un puesto comercial
# T=2405.10 clienteE572: COLA EMERGENCIA - llegue con un IA: 38.94
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# T=2405.10, clienteE572: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:22, e:14]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE572: 337.88
# T=2416.75 clienteE573: COLA EMERGENCIA - llegue con un IA: 11.65
# Atendiendo:[c:22, e:14]
# En cola:[c:0, e:0]
# T=2416.75, clienteE573: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:23, e:15]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE573: 116.02
# T=2429.71 clienteE574: COLA EMERGENCIA - llegue con un IA: 12.96
# Atendiendo:[c:23, e:15]
# En cola:[c:0, e:0]
# T=2429.71, clienteE574: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE574: 527.15
# T=2466.96 clienteC575: COLA COMERCIAL - llegue con un IA: 37.26
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# T=2466.96, clienteC575: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC575: 474.04
# T=2492.45 clienteC576: COLA COMERCIAL - llegue con un IA: 25.49
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# T=2492.45, clienteC576: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC576: 72.53
# T=2532.76, clienteE573: Sali de un puesto de emergencia
# T=2538.85 clienteC577: COLA COMERCIAL - llegue con un IA: 46.40
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# T=2538.85, clienteC577: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC577: 97.39
# T=2564.98, clienteC576: Sali de un puesto comercial
# T=2576.27 clienteC578: COLA COMERCIAL - llegue con un IA: 37.42
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# T=2576.27, clienteC578: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC578: 325.16
# T=2598.54, clienteC561: Sali de un puesto comercial
# T=2611.50, clienteC568: Sali de un puesto comercial
# T=2617.69 clienteC579: COLA COMERCIAL - llegue con un IA: 41.42
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# T=2617.69, clienteC579: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC579: 466.94
# T=2628.02, clienteC570: Sali de un puesto comercial
# T=2636.25, clienteC577: Sali de un puesto comercial
# T=2638.50, clienteC566: Sali de un puesto comercial
# T=2664.99, clienteC569: Sali de un puesto comercial
# T=2671.22 clienteC580: COLA COMERCIAL - llegue con un IA: 53.53
# Atendiendo:[c:22, e:16]
# En cola:[c:0, e:0]
# T=2671.22, clienteC580: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC580: 530.03
# T=2693.40 clienteC581: COLA COMERCIAL - llegue con un IA: 22.18
# Atendiendo:[c:23, e:16]
# En cola:[c:0, e:0]
# T=2693.40, clienteC581: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC581: 290.13
# T=2708.24, clienteC571: Sali de un puesto comercial
# T=2714.43 clienteC582: COLA COMERCIAL - llegue con un IA: 21.03
# Atendiendo:[c:23, e:16]
# En cola:[c:0, e:0]
# T=2714.43, clienteC582: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC582:  6.63
# T=2721.06, clienteC582: Sali de un puesto comercial
# T=2727.85, clienteC564: Sali de un puesto comercial
# T=2742.98, clienteE572: Sali de un puesto de emergencia
# T=2756.43 clienteC583: COLA COMERCIAL - llegue con un IA: 42.01
# Atendiendo:[c:22, e:16]
# En cola:[c:0, e:0]
# T=2756.43, clienteC583: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC583: 187.70
# T=2773.93 clienteC584: COLA COMERCIAL - llegue con un IA: 17.49
# Atendiendo:[c:23, e:16]
# En cola:[c:0, e:0]
# T=2773.93, clienteC584: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC584: 401.28
# T=2793.71 clienteC585: COLA COMERCIAL - llegue con un IA: 19.78
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# T=2793.71, clienteC585: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC585: 308.74
# T=2803.24, clienteC567: Sali de un puesto comercial
# T=2819.62 clienteC586: COLA COMERCIAL - llegue con un IA: 25.92
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# T=2819.62, clienteC586: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC586: 123.88
# T=2825.97 clienteC587: COLA COMERCIAL - llegue con un IA:  6.35
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# T=2825.97, clienteC587: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC587: 348.09
# T=2854.01 clienteC588: COLA COMERCIAL - llegue con un IA: 28.04
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# T=2854.01, clienteC588: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC588: 289.40
# T=2885.07 clienteC589: COLA COMERCIAL - llegue con un IA: 31.06
# Atendiendo:[c:27, e:16]
# En cola:[c:0, e:0]
# T=2885.07, clienteC589: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC589: 125.30
# T=2901.43, clienteC578: Sali de un puesto comercial
# T=2924.33 clienteC590: COLA COMERCIAL - llegue con un IA: 39.25
# Atendiendo:[c:27, e:16]
# En cola:[c:0, e:0]
# T=2924.33, clienteC590: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC590: 499.85
# T=2941.01, clienteC575: Sali de un puesto comercial
# T=2943.50, clienteC586: Sali de un puesto comercial
# T=2944.13, clienteC583: Sali de un puesto comercial
# T=2956.86, clienteE574: Sali de un puesto de emergencia
# T=2964.46 clienteC591: COLA COMERCIAL - llegue con un IA: 40.13
# Atendiendo:[c:25, e:16]
# En cola:[c:0, e:0]
# T=2964.46, clienteC591: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:16]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC591:  6.82
# T=2971.28, clienteC591: Sali de un puesto comercial
# T=2983.53, clienteC581: Sali de un puesto comercial
# T=3009.79 clienteE592: COLA EMERGENCIA - llegue con un IA: 45.33
# Atendiendo:[c:24, e:16]
# En cola:[c:0, e:0]
# T=3009.79, clienteE592: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE592: 487.03
# T=3010.38, clienteC589: Sali de un puesto comercial
# T=3022.07 clienteC593: COLA COMERCIAL - llegue con un IA: 12.28
# Atendiendo:[c:24, e:17]
# En cola:[c:0, e:0]
# T=3022.07, clienteC593: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC593: 269.82
# T=3063.70 clienteC594: COLA COMERCIAL - llegue con un IA: 41.63
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# T=3063.70, clienteC594: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC594: 236.59
# T=3084.64, clienteC579: Sali de un puesto comercial
# T=3102.44, clienteC585: Sali de un puesto comercial
# T=3103.50 clienteC595: COLA COMERCIAL - llegue con un IA: 39.80
# Atendiendo:[c:24, e:17]
# En cola:[c:0, e:0]
# T=3103.50, clienteC595: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC595: 82.20
# T=3116.06 clienteC596: COLA COMERCIAL - llegue con un IA: 12.56
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# T=3116.06, clienteC596: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC596: 53.94
# T=3130.85 clienteC597: COLA COMERCIAL - llegue con un IA: 14.78
# Atendiendo:[c:26, e:17]
# En cola:[c:0, e:0]
# T=3130.85, clienteC597: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC597: 129.96
# T=3143.41, clienteC588: Sali de un puesto comercial
# T=3164.39 clienteC598: COLA COMERCIAL - llegue con un IA: 33.54
# Atendiendo:[c:26, e:17]
# En cola:[c:0, e:0]
# T=3164.39, clienteC598: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC598: 270.11
# T=3170.01, clienteC596: Sali de un puesto comercial
# T=3174.07, clienteC587: Sali de un puesto comercial
# T=3175.21, clienteC584: Sali de un puesto comercial
# T=3185.71, clienteC595: Sali de un puesto comercial
# T=3185.71 clienteC599: COLA COMERCIAL - llegue con un IA: 21.32
# Atendiendo:[c:23, e:17]
# En cola:[c:0, e:0]
# T=3185.71, clienteC599: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC599: 550.94
# T=3201.26, clienteC580: Sali de un puesto comercial
# T=3208.85 clienteC600: COLA COMERCIAL - llegue con un IA: 23.13
# Atendiendo:[c:23, e:17]
# En cola:[c:0, e:0]
# T=3208.85, clienteC600: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC600: 521.32
# T=3226.72 clienteC601: COLA COMERCIAL - llegue con un IA: 17.87
# Atendiendo:[c:24, e:17]
# En cola:[c:0, e:0]
# T=3226.72, clienteC601: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC601: 79.82
# T=3232.09 clienteE602: COLA EMERGENCIA - llegue con un IA:  5.38
# Atendiendo:[c:25, e:17]
# En cola:[c:0, e:0]
# T=3232.09, clienteE602: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:26, e:18]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE602: 201.36
# T=3260.80, clienteC597: Sali de un puesto comercial
# T=3281.12 clienteC603: COLA COMERCIAL - llegue con un IA: 49.03
# Atendiendo:[c:25, e:18]
# En cola:[c:0, e:0]
# T=3281.12, clienteC603: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:18]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC603: 138.75
# T=3291.90, clienteC593: Sali de un puesto comercial
# T=3300.29, clienteC594: Sali de un puesto comercial
# T=3306.54, clienteC601: Sali de un puesto comercial
# T=3327.69 clienteC604: COLA COMERCIAL - llegue con un IA: 46.57
# Atendiendo:[c:23, e:18]
# En cola:[c:0, e:0]
# T=3327.69, clienteC604: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:18]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC604: 285.27
# T=3351.02 clienteC605: COLA COMERCIAL - llegue con un IA: 23.33
# Atendiendo:[c:24, e:18]
# En cola:[c:0, e:0]
# T=3351.02, clienteC605: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:18]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC605: 561.97
# T=3404.28 clienteC606: COLA COMERCIAL - llegue con un IA: 53.26
# Atendiendo:[c:25, e:18]
# En cola:[c:0, e:0]
# T=3404.28, clienteC606: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:18]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC606: 410.11
# T=3419.87, clienteC603: Sali de un puesto comercial
# T=3424.18, clienteC590: Sali de un puesto comercial
# T=3427.10 clienteE607: COLA EMERGENCIA - llegue con un IA: 22.82
# Atendiendo:[c:24, e:18]
# En cola:[c:0, e:0]
# T=3427.10, clienteE607: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE607: 546.31
# T=3433.45, clienteE602: Sali de un puesto de emergencia
# T=3434.50, clienteC598: Sali de un puesto comercial
# T=3436.81 clienteC608: COLA COMERCIAL - llegue con un IA:  9.71
# Atendiendo:[c:24, e:19]
# En cola:[c:0, e:0]
# T=3436.81, clienteC608: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC608: 406.74
# T=3494.11 clienteC609: COLA COMERCIAL - llegue con un IA: 57.30
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# T=3494.11, clienteC609: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC609: 308.91
# T=3496.82, clienteE592: Sali de un puesto de emergencia
# T=3533.83 clienteC610: COLA COMERCIAL - llegue con un IA: 39.72
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# T=3533.83, clienteC610: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC610: 297.30
# T=3585.23 clienteC611: COLA COMERCIAL - llegue con un IA: 51.40
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# T=3585.23, clienteC611: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC611: 184.27
# T=3612.96, clienteC604: Sali de un puesto comercial
# T=3618.76 clienteC612: COLA COMERCIAL - llegue con un IA: 33.53
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# T=3618.76, clienteC612: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC612: 598.83
# T=3637.86 clienteC613: COLA COMERCIAL - llegue con un IA: 19.10
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# T=3637.86, clienteC613: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:29, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC613: 282.43
# T=3686.36 clienteC614: COLA COMERCIAL - llegue con un IA: 48.50
# Atendiendo:[c:29, e:19]
# En cola:[c:0, e:0]
# T=3686.36, clienteC614: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC614: 146.44
# T=3691.29 clienteC615: COLA COMERCIAL - llegue con un IA:  4.92
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# T=3691.29, clienteC615: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC615: 33.27
# T=3699.64 clienteC616: COLA COMERCIAL - llegue con un IA:  8.35
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# T=3699.64, clienteC616: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:32, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC616: 216.39
# T=3724.55, clienteC615: Sali de un puesto comercial
# T=3730.17, clienteC600: Sali de un puesto comercial
# T=3730.61 clienteC617: COLA COMERCIAL - llegue con un IA: 30.97
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# T=3730.61, clienteC617: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC617: 172.80
# T=3736.66, clienteC599: Sali de un puesto comercial
# T=3739.54 clienteC618: COLA COMERCIAL - llegue con un IA:  8.93
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# T=3739.54, clienteC618: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC618: 494.08
# T=3769.50, clienteC611: Sali de un puesto comercial
# T=3799.19 clienteC619: COLA COMERCIAL - llegue con un IA: 59.65
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# T=3799.19, clienteC619: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC619: 410.82
# T=3803.02, clienteC609: Sali de un puesto comercial
# T=3814.39, clienteC606: Sali de un puesto comercial
# T=3831.13, clienteC610: Sali de un puesto comercial
# T=3832.80, clienteC614: Sali de un puesto comercial
# T=3840.95 clienteC620: COLA COMERCIAL - llegue con un IA: 41.76
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# T=3840.95, clienteC620: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC620: 142.94
# T=3843.56, clienteC608: Sali de un puesto comercial
# T=3891.89 clienteC621: COLA COMERCIAL - llegue con un IA: 50.94
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# T=3891.89, clienteC621: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC621: 66.91
# T=3903.41, clienteC617: Sali de un puesto comercial
# T=3912.99, clienteC605: Sali de un puesto comercial
# T=3916.03, clienteC616: Sali de un puesto comercial
# T=3920.29, clienteC613: Sali de un puesto comercial
# T=3928.76 clienteC622: COLA COMERCIAL - llegue con un IA: 36.87
# Atendiendo:[c:24, e:19]
# En cola:[c:0, e:0]
# T=3928.76, clienteC622: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC622: 317.98
# T=3933.10 clienteC623: COLA COMERCIAL - llegue con un IA:  4.34
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# T=3933.10, clienteC623: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC623: 73.17
# T=3958.79, clienteC621: Sali de un puesto comercial
# T=3973.41, clienteE607: Sali de un puesto de emergencia
# T=3975.39 clienteC624: COLA COMERCIAL - llegue con un IA: 42.29
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# T=3975.39, clienteC624: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC624: 378.95
# T=3983.89, clienteC620: Sali de un puesto comercial
# T=3991.76 clienteC625: COLA COMERCIAL - llegue con un IA: 16.37
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# T=3991.76, clienteC625: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC625: 116.18
# T=4006.27, clienteC623: Sali de un puesto comercial
# T=4010.91 clienteC626: COLA COMERCIAL - llegue con un IA: 19.14
# Atendiendo:[c:25, e:19]
# En cola:[c:0, e:0]
# T=4010.91, clienteC626: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC626: 280.01
# T=4029.29 clienteC627: COLA COMERCIAL - llegue con un IA: 18.39
# Atendiendo:[c:26, e:19]
# En cola:[c:0, e:0]
# T=4029.29, clienteC627: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC627: 511.60
# T=4035.28 clienteC628: COLA COMERCIAL - llegue con un IA:  5.99
# Atendiendo:[c:27, e:19]
# En cola:[c:0, e:0]
# T=4035.28, clienteC628: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC628: 495.04
# T=4063.33 clienteC629: COLA COMERCIAL - llegue con un IA: 28.05
# Atendiendo:[c:28, e:19]
# En cola:[c:0, e:0]
# T=4063.33, clienteC629: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:29, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC629: 244.65
# T=4088.57 clienteC630: COLA COMERCIAL - llegue con un IA: 25.24
# Atendiendo:[c:29, e:19]
# En cola:[c:0, e:0]
# T=4088.57, clienteC630: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC630: 57.76
# T=4098.22 clienteC631: COLA COMERCIAL - llegue con un IA:  9.66
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# T=4098.22, clienteC631: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:31, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC631: 93.66
# T=4107.95, clienteC625: Sali de un puesto comercial
# T=4146.32, clienteC630: Sali de un puesto comercial
# T=4149.33 clienteC632: COLA COMERCIAL - llegue con un IA: 51.10
# Atendiendo:[c:29, e:19]
# En cola:[c:0, e:0]
# T=4149.33, clienteC632: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:30, e:19]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC632: 121.32
# T=4191.89, clienteC631: Sali de un puesto comercial
# ...
# T=12945.39, clienteE922: Sali de un puesto de emergencia
# T=12947.86 clienteC924: COLA COMERCIAL - llegue con un IA: 34.99
# Atendiendo:[c:53, e:20]
# En cola:[c:0, e:25]
# T=12947.86, clienteC924: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:25]
# Tiempo de Atencion generado para clienteC924: 132.82
# T=12979.76 clienteC925: COLA COMERCIAL - llegue con un IA: 31.90
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:25]
# T=12979.76, clienteC925: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:25]
# Tiempo de Atencion generado para clienteC925: 19.87
# T=12995.59, clienteC917: Sali de un puesto comercial
# T=12999.63, clienteC925: Sali de un puesto comercial
# T=13013.49, clienteC912: Sali de un puesto comercial
# T=13027.02 clienteC926: COLA COMERCIAL - llegue con un IA: 47.27
# Atendiendo:[c:52, e:20]
# En cola:[c:0, e:25]
# T=13027.02, clienteC926: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:53, e:20]
# En cola:[c:0, e:25]
# Tiempo de Atencion generado para clienteC926: 17.48
# T=13034.21, clienteC921: Sali de un puesto comercial
# T=13044.51, clienteC926: Sali de un puesto comercial
# T=13062.10, clienteC914: Sali de un puesto comercial
# T=13078.62 clienteE927: COLA EMERGENCIA - llegue con un IA: 51.59
# Atendiendo:[c:50, e:20]
# En cola:[c:0, e:25]
# T=13078.62, clienteE927: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:26]
# Tiempo de Atencion generado para clienteE927: 119.48
# T=13080.67, clienteC924: Sali de un puesto comercial
# T=13084.92 clienteC928: COLA COMERCIAL - llegue con un IA:  6.30
# Atendiendo:[c:50, e:20]
# En cola:[c:0, e:26]
# T=13084.92, clienteC928: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:26]
# Tiempo de Atencion generado para clienteC928: 505.43
# T=13096.15, clienteC918: Sali de un puesto comercial
# T=13127.38 clienteC929: COLA COMERCIAL - llegue con un IA: 42.46
# Atendiendo:[c:50, e:20]
# En cola:[c:0, e:26]
# T=13127.38, clienteC929: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:26]
# Tiempo de Atencion generado para clienteC929: 143.38
# T=13186.30 clienteC930: COLA COMERCIAL - llegue con un IA: 58.92
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:26]
# T=13186.30, clienteC930: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:52, e:20]
# En cola:[c:0, e:26]
# Tiempo de Atencion generado para clienteC930: 472.76
# T=13198.09, clienteE927: Sali de un puesto de emergencia
# T=13221.80, clienteC916: Sali de un puesto comercial
# T=13232.58, clienteC919: Sali de un puesto comercial
# T=13235.73 clienteE931: COLA EMERGENCIA - llegue con un IA: 49.44
# Atendiendo:[c:50, e:20]
# En cola:[c:0, e:26]
# T=13235.73, clienteE931: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:27]
# Tiempo de Atencion generado para clienteE931:  6.15
# T=13241.88, clienteE931: Sali de un puesto de emergencia
# T=13248.22 clienteC932: COLA COMERCIAL - llegue con un IA: 12.49
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:27]
# T=13248.22, clienteC932: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:52, e:20]
# En cola:[c:0, e:27]
# Tiempo de Atencion generado para clienteC932: 534.65
# T=13251.48, clienteC923: Sali de un puesto comercial
# T=13270.75, clienteC929: Sali de un puesto comercial
# T=13275.14 clienteC933: COLA COMERCIAL - llegue con un IA: 26.92
# Atendiendo:[c:50, e:20]
# En cola:[c:0, e:27]
# T=13275.14, clienteC933: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:27]
# Tiempo de Atencion generado para clienteC933: 534.27
# T=13314.00 clienteE934: COLA EMERGENCIA - llegue con un IA: 38.86
# Atendiendo:[c:51, e:20]
# En cola:[c:0, e:27]
# T=13314.00, clienteE934: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:52, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteE934: 147.56
# T=13333.63 clienteC935: COLA COMERCIAL - llegue con un IA: 19.63
# Atendiendo:[c:52, e:20]
# En cola:[c:0, e:28]
# T=13333.63, clienteC935: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:53, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC935: 551.98
# T=13377.32 clienteC936: COLA COMERCIAL - llegue con un IA: 43.69
# Atendiendo:[c:53, e:20]
# En cola:[c:0, e:28]
# T=13377.32, clienteC936: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC936: 190.14
# T=13379.44 clienteC937: COLA COMERCIAL - llegue con un IA:  2.12
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:28]
# T=13379.44, clienteC937: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC937: 168.87
# T=13416.07 clienteC938: COLA COMERCIAL - llegue con un IA: 36.63
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=13416.07, clienteC938: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC938: 92.74
# T=13457.22 clienteC939: COLA COMERCIAL - llegue con un IA: 41.15
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# T=13457.22, clienteC939: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC939: 83.55
# T=13461.56, clienteE934: Sali de un puesto de emergencia
# T=13468.62 clienteC940: COLA COMERCIAL - llegue con un IA: 11.40
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13468.62, clienteC940: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC940: 16.90
# T=13485.52, clienteC940: Sali de un puesto comercial
# T=13496.56 clienteC941: COLA COMERCIAL - llegue con un IA: 27.94
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13496.56, clienteC941: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC941: 421.73
# T=13498.54 clienteC942: COLA COMERCIAL - llegue con un IA:  1.97
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# T=13498.54, clienteC942: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC942: 69.68
# T=13508.81, clienteC938: Sali de un puesto comercial
# T=13528.78 clienteC943: COLA COMERCIAL - llegue con un IA: 30.25
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# T=13528.78, clienteC943: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC943: 87.73
# T=13540.77, clienteC939: Sali de un puesto comercial
# T=13548.31, clienteC937: Sali de un puesto comercial
# T=13548.67 clienteC944: COLA COMERCIAL - llegue con un IA: 19.88
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13548.67, clienteC944: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC944: 227.48
# T=13567.46, clienteC936: Sali de un puesto comercial
# T=13568.21, clienteC942: Sali de un puesto comercial
# T=13590.35, clienteC928: Sali de un puesto comercial
# T=13604.61 clienteC945: COLA COMERCIAL - llegue con un IA: 55.94
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=13604.61, clienteC945: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC945: 377.82
# T=13616.51, clienteC943: Sali de un puesto comercial
# T=13640.73 clienteC946: COLA COMERCIAL - llegue con un IA: 36.13
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=13640.73, clienteC946: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC946: 195.45
# T=13659.06, clienteC930: Sali de un puesto comercial
# T=13673.26 clienteC947: COLA COMERCIAL - llegue con un IA: 32.53
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=13673.26, clienteC947: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC947: 349.81
# T=13681.18 clienteC948: COLA COMERCIAL - llegue con un IA:  7.92
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# T=13681.18, clienteC948: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC948: 306.21
# T=13715.93 clienteC949: COLA COMERCIAL - llegue con un IA: 34.74
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13715.93, clienteC949: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC949: 294.95
# T=13746.19 clienteC950: COLA COMERCIAL - llegue con un IA: 30.27
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# T=13746.19, clienteC950: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC950: 195.86
# T=13771.11 clienteC951: COLA COMERCIAL - llegue con un IA: 24.92
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# T=13771.11, clienteC951: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC951: 561.76
# T=13776.15, clienteC944: Sali de un puesto comercial
# T=13782.87, clienteC932: Sali de un puesto comercial
# T=13809.41, clienteC933: Sali de un puesto comercial
# T=13809.90 clienteC952: COLA COMERCIAL - llegue con un IA: 38.78
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13809.90, clienteC952: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC952: 40.04
# T=13836.18, clienteC946: Sali de un puesto comercial
# T=13846.29 clienteC953: COLA COMERCIAL - llegue con un IA: 36.39
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13846.29, clienteC953: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC953: 612.62
# T=13849.93, clienteC952: Sali de un puesto comercial
# T=13869.34 clienteC954: COLA COMERCIAL - llegue con un IA: 23.05
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13869.34, clienteC954: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC954: 308.23
# T=13885.62, clienteC935: Sali de un puesto comercial
# T=13913.30 clienteC955: COLA COMERCIAL - llegue con un IA: 43.96
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13913.30, clienteC955: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC955: 72.51
# T=13918.29, clienteC941: Sali de un puesto comercial
# T=13938.55 clienteC956: COLA COMERCIAL - llegue con un IA: 25.25
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=13938.55, clienteC956: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC956: 457.30
# T=13942.06, clienteC950: Sali de un puesto comercial
# T=13982.42, clienteC945: Sali de un puesto comercial
# T=13985.81, clienteC955: Sali de un puesto comercial
# T=13987.40, clienteC948: Sali de un puesto comercial
# T=13996.87 clienteC957: COLA COMERCIAL - llegue con un IA: 58.31
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:28]
# T=13996.87, clienteC957: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC957: 316.26
# T=14008.38 clienteC958: COLA COMERCIAL - llegue con un IA: 11.52
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=14008.38, clienteC958: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC958: 514.46
# T=14010.88, clienteC949: Sali de un puesto comercial
# T=14023.07, clienteC947: Sali de un puesto comercial
# T=14046.95 clienteC959: COLA COMERCIAL - llegue con un IA: 38.57
# Atendiendo:[c:54, e:20]
# En cola:[c:0, e:28]
# T=14046.95, clienteC959: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC959: 191.11
# T=14062.21 clienteC960: COLA COMERCIAL - llegue con un IA: 15.26
# Atendiendo:[c:55, e:20]
# En cola:[c:0, e:28]
# T=14062.21, clienteC960: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC960: 494.69
# T=14105.09 clienteC961: COLA COMERCIAL - llegue con un IA: 42.88
# Atendiendo:[c:56, e:20]
# En cola:[c:0, e:28]
# T=14105.09, clienteC961: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC961: 471.02
# T=14134.54 clienteC962: COLA COMERCIAL - llegue con un IA: 29.44
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=14134.54, clienteC962: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC962: 223.37
# T=14177.57, clienteC954: Sali de un puesto comercial
# T=14188.58 clienteC963: COLA COMERCIAL - llegue con un IA: 54.04
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:28]
# T=14188.58, clienteC963: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC963: 218.70
# T=14215.37 clienteC964: COLA COMERCIAL - llegue con un IA: 26.79
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# T=14215.37, clienteC964: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC964: 390.21
# T=14238.06, clienteC959: Sali de un puesto comercial
# T=14262.45 clienteC965: COLA COMERCIAL - llegue con un IA: 47.08
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:28]
# T=14262.45, clienteC965: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# Tiempo de Atencion generado para clienteC965: 145.43
# T=14269.77 clienteE966: COLA EMERGENCIA - llegue con un IA:  7.33
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:28]
# T=14269.77, clienteE966: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:29]
# Tiempo de Atencion generado para clienteE966: 178.40
# T=14281.57 clienteC967: COLA COMERCIAL - llegue con un IA: 11.79
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:29]
# T=14313.13, clienteC957: Sali de un puesto comercial
# T=14313.13, clienteC967: COLA COMERCIAL - Me atendieron despues de esperar 31.56
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:29]
# Tiempo de Atencion generado para clienteC967: 332.90
# T=14316.31 clienteE968: COLA EMERGENCIA - llegue con un IA: 34.74
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:29]
# T=14332.87, clienteC951: Sali de un puesto comercial
# T=14332.87, clienteE968: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 16.56
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:30]
# Tiempo de Atencion generado para clienteE968: 112.81
# T=14347.57 clienteC969: COLA COMERCIAL - llegue con un IA: 31.27
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:30]
# T=14357.90, clienteC962: Sali de un puesto comercial
# T=14357.90, clienteC969: COLA COMERCIAL - Me atendieron despues de esperar 10.33
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:30]
# Tiempo de Atencion generado para clienteC969: 567.00
# T=14370.10 clienteC970: COLA COMERCIAL - llegue con un IA: 22.53
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:30]
# T=14395.85, clienteC956: Sali de un puesto comercial
# T=14395.85, clienteC970: COLA COMERCIAL - Me atendieron despues de esperar 25.75
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:30]
# Tiempo de Atencion generado para clienteC970: 459.15

# %% [markdown]
# Results

# %%
print("===========================================================================")
print("RESULTADOS:")
print("Clientes totales: %1d"%ci["NT"])
PEC = (ci["NEC"] / ci["NT"]) * 100
# Porcentaje de espera menor a 40 segundos
print("Porcentaje de espera en cola menor a 40 segundos: %5.2f"%PEC)
# Objetio: Mayor o igual al 90%

print('Cantidad de puestos comerciales',cantCom)
print('Cantidad de puestos de emergencia',cantEmer)
#print("Cantidad de personales multitasking",ci["multitasking"])
# Out:
# ===========================================================================
# RESULTADOS:
# Clientes totales: 971
# Porcentaje de espera en cola menor a 40 segundos: 85.58
# Cantidad de puestos comerciales 60
# Cantidad de puestos de emergencia 20
