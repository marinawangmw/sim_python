# %% [markdown]
# import the SimPy package

# %%
#from simpy import initialize
#from SimPy.Simulation import *
import simpy
import random
import collections

# %% [markdown]
# _____

# %%
def distribucion_llegada(env,puestos,cont,n):
    while True:
    #for i in range(n):
        cont["NT"] += 1
        r = random.random()
        #print("Distribucion de generacion de tipo de cliente: %5.2f"%r)
        if r <= cont["PE"]:
            ce = Customer(name = "clienteE%02d"%cont["NT"])
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA EMERGENCIA - llegue con un IA: %5.2f"%(env.now,ce.name,ia))
            colas(puestos)
            env.process(ce.llamada_emergencia(env,puestos,cont))
        else: 
            cc = Customer(name = "clienteC%02d"%cont["NT"])
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA COMERCIAL - llegue con un IA: %5.2f"%(env.now,cc.name,ia))
            colas(puestos)
            env.process(cc.llamada_comercial(env,puestos,cont))

# %%
class Customer():
    """Evento llegadas/llamadas de los clientes"""
    def __init__(self,name):
        self.name = name
        
    def llamada_emergencia(self,env,puestos,cont):
        arrive = env.now
        # Pido uso de los dos puestos, y me dan el primero que se libere
        emergencia, comercial = puestos[1].request(priority=0), puestos[0].request(priority=0)
        atendido = yield emergencia | comercial 
        #assert atendido == {emergencia}
        
        # Me atendieron por puestos comerciales?
        if comercial in atendido:
            cont["multitasking"]+=1
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de emergencia"%(env.now,self.name))
            
        else:
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
            
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de emergencia"%(env.now,self.name))
            
            
    def llamada_comercial(self,env,puestos,cont):
        arrive = env.now
        with puestos[0].request(priority=1) as request:
            yield request
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA COMERCIAL - Me atendieron despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto comercial"%(env.now,self.name))

# %%
def colas(p):
    print ("Atendiendo:[c:%1d, e:%1d]"%(p[0].count,p[1].count))
    print ("En cola:[c:%1d, e:%1d]"%(len(p[0].queue),len(p[1].queue)))

# %%
def generar_TA(cont):
    #(a=5,b=615)
    a=5
    b=615
    ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
    
    while ta<a: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta>b:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta>b:
                continue
            else:
                break
        
    while ta>b: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta<a:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta<a:
                continue
            else:
                break
            
    return ta

# %% [markdown]
# Condiciones Iniciales

# %%
# Experimental data
NT = 0
maxTime = 14400 #segundos
maxClient = 10000
#random.seed(RANDOM_SEED)
PE = 0.12 #Porcentaje Emergencia
PC = 0.88 #Porcentaje Comercial
NEC = 0 #Cantidad de gente que espero en cola menor a 40 segundos
PEC = 0.0 #Porcentaje de espera en cola menor a 40 segundos

# TA - distribucion normal
mu = 267.64 
sigma = 297.40

# IA - uniforme
IAMin = 1
IAMax = 60

# Contadores
ci = {"multitasking":0,
     "mu":mu,
     "sigma":sigma,
     "min":IAMin,
     "max":IAMax,
     "PE":PE,
     "PC":PC,
     "emer":0,
     "com":0,
     "NEC":NEC,
     "NT":NT}

# %%
# Puestos de atencion - variables de control
print('Ingrese cantidad de puestos comerciales')
cantCom = int(input())
ci["com"] = cantCom
print('Ingrese cantidad de puestos de emergencia')
cantEmer = int(input())
ci["emer"] = cantEmer
# Out:
# Ingrese cantidad de puestos comerciales
# 60
# Ingrese cantidad de puestos de emergencia
# 20

# %% [markdown]
# Modelo de Simulacion

# %%
env = simpy.Environment()
puestos = [simpy.PriorityResource(env,capacity=cantCom),
           simpy.PriorityResource(env,capacity=cantEmer)] # menor el numero priority, mayor es la prioridad
           
env.process(distribucion_llegada(env,puestos,ci,n=maxClient))
env.run(until=maxTime)
# Out:
# T=50.79 clienteC01: COLA COMERCIAL - llegue con un IA: 50.79
# Atendiendo:[c:0, e:0]
# En cola:[c:0, e:0]
# T=50.79, clienteC01: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC01: 591.14
# T=69.93 clienteC02: COLA COMERCIAL - llegue con un IA: 19.14
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# T=69.93, clienteC02: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC02: 455.71
# T=71.03 clienteC03: COLA COMERCIAL - llegue con un IA:  1.10
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# T=71.03, clienteC03: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC03: 161.84
# T=74.76 clienteC04: COLA COMERCIAL - llegue con un IA:  3.73
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# T=74.76, clienteC04: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC04: 46.38
# T=97.41 clienteC05: COLA COMERCIAL - llegue con un IA: 22.65
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# T=97.41, clienteC05: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC05: 96.34
# T=121.14, clienteC04: Sali de un puesto comercial
# T=140.36 clienteC06: COLA COMERCIAL - llegue con un IA: 42.95
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# T=140.36, clienteC06: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC06: 266.80
# T=169.93 clienteC07: COLA COMERCIAL - llegue con un IA: 29.57
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# T=169.93, clienteC07: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:6, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC07: 509.10
# T=181.04 clienteC08: COLA COMERCIAL - llegue con un IA: 11.11
# Atendiendo:[c:6, e:0]
# En cola:[c:0, e:0]
# T=181.04, clienteC08: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:7, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC08: 126.74
# T=193.75, clienteC05: Sali de un puesto comercial
# T=199.88 clienteE09: COLA EMERGENCIA - llegue con un IA: 18.83
# Atendiendo:[c:6, e:0]
# En cola:[c:0, e:0]
# T=199.88, clienteE09: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE09: 546.83
# T=230.35 clienteC10: COLA COMERCIAL - llegue con un IA: 30.47
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=230.35, clienteC10: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC10: 187.25
# T=232.87, clienteC03: Sali de un puesto comercial
# T=289.16 clienteC11: COLA COMERCIAL - llegue con un IA: 58.81
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=289.16, clienteC11: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC11: 265.82
# T=307.78, clienteC08: Sali de un puesto comercial
# T=308.36 clienteC12: COLA COMERCIAL - llegue con un IA: 19.21
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=308.36, clienteC12: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC12:  9.64
# T=318.01, clienteC12: Sali de un puesto comercial
# T=364.82 clienteC13: COLA COMERCIAL - llegue con un IA: 56.46
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=364.82, clienteC13: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC13: 439.25
# T=394.51 clienteC14: COLA COMERCIAL - llegue con un IA: 29.69
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=394.51, clienteC14: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC14: 218.29
# T=407.16, clienteC06: Sali de un puesto comercial
# T=417.59, clienteC10: Sali de un puesto comercial
# T=452.88 clienteC15: COLA COMERCIAL - llegue con un IA: 58.37
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=452.88, clienteC15: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC15: 318.75
# T=497.57 clienteC16: COLA COMERCIAL - llegue con un IA: 44.69
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=497.57, clienteC16: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC16: 329.71
# T=525.64, clienteC02: Sali de un puesto comercial
# T=535.29 clienteC17: COLA COMERCIAL - llegue con un IA: 37.71
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=535.29, clienteC17: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC17: 365.01
# T=554.98, clienteC11: Sali de un puesto comercial
# T=587.11 clienteC18: COLA COMERCIAL - llegue con un IA: 51.83
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=587.11, clienteC18: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC18: 20.24
# T=589.13 clienteC19: COLA COMERCIAL - llegue con un IA:  2.01
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# T=589.13, clienteC19: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC19: 226.40
# T=607.36, clienteC18: Sali de un puesto comercial
# T=612.80, clienteC14: Sali de un puesto comercial
# T=635.95 clienteE20: COLA EMERGENCIA - llegue con un IA: 46.82
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=635.95, clienteE20: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE20: 141.16
# T=641.93, clienteC01: Sali de un puesto comercial
# T=660.18 clienteC21: COLA COMERCIAL - llegue con un IA: 24.23
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=660.18, clienteC21: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC21: 59.45
# T=679.03, clienteC07: Sali de un puesto comercial
# T=706.22 clienteC22: COLA COMERCIAL - llegue con un IA: 46.04
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=706.22, clienteC22: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC22: 431.69
# T=719.63, clienteC21: Sali de un puesto comercial
# T=731.16 clienteC23: COLA COMERCIAL - llegue con un IA: 24.94
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=731.16, clienteC23: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC23: 411.91
# T=746.71, clienteE09: Sali de un puesto de emergencia
# T=753.39 clienteC24: COLA COMERCIAL - llegue con un IA: 22.23
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# T=753.39, clienteC24: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC24: 154.24
# T=771.63, clienteC15: Sali de un puesto comercial
# T=777.10, clienteE20: Sali de un puesto de emergencia
# T=804.07, clienteC13: Sali de un puesto comercial
# T=810.84 clienteC25: COLA COMERCIAL - llegue con un IA: 57.46
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=810.84, clienteC25: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC25: 202.16
# T=814.96 clienteC26: COLA COMERCIAL - llegue con un IA:  4.12
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# T=814.96, clienteC26: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC26: 75.32
# T=815.52, clienteC19: Sali de un puesto comercial
# T=827.28, clienteC16: Sali de un puesto comercial
# T=835.26 clienteC27: COLA COMERCIAL - llegue con un IA: 20.30
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=835.26, clienteC27: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC27: 471.90
# T=879.50 clienteC28: COLA COMERCIAL - llegue con un IA: 44.24
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# T=879.50, clienteC28: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC28: 234.21
# T=890.28, clienteC26: Sali de un puesto comercial
# T=900.29, clienteC17: Sali de un puesto comercial
# T=907.62, clienteC24: Sali de un puesto comercial
# T=910.32 clienteC29: COLA COMERCIAL - llegue con un IA: 30.82
# Atendiendo:[c:7, e:2]
# En cola:[c:0, e:0]
# T=910.32, clienteC29: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC29: 142.67
# T=914.52 clienteC30: COLA COMERCIAL - llegue con un IA:  4.21
# Atendiendo:[c:8, e:2]
# En cola:[c:0, e:0]
# T=914.52, clienteC30: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC30: 249.48
# T=940.97 clienteC31: COLA COMERCIAL - llegue con un IA: 26.45
# Atendiendo:[c:9, e:2]
# En cola:[c:0, e:0]
# T=940.97, clienteC31: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC31: 470.18
# T=984.33 clienteC32: COLA COMERCIAL - llegue con un IA: 43.36
# Atendiendo:[c:10, e:2]
# En cola:[c:0, e:0]
# T=984.33, clienteC32: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC32: 42.00
# T=1007.40 clienteC33: COLA COMERCIAL - llegue con un IA: 23.07
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# T=1007.40, clienteC33: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC33: 380.28
# T=1013.00, clienteC25: Sali de un puesto comercial
# T=1015.82 clienteE34: COLA EMERGENCIA - llegue con un IA:  8.41
# Atendiendo:[c:11, e:2]
# En cola:[c:0, e:0]
# T=1015.82, clienteE34: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE34: 149.98
# T=1026.34, clienteC32: Sali de un puesto comercial
# T=1049.93 clienteC35: COLA COMERCIAL - llegue con un IA: 34.11
# Atendiendo:[c:11, e:3]
# En cola:[c:0, e:0]
# T=1049.93, clienteC35: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC35: 87.26
# T=1052.98, clienteC29: Sali de un puesto comercial
# T=1092.55 clienteE36: COLA EMERGENCIA - llegue con un IA: 42.61
# Atendiendo:[c:11, e:3]
# En cola:[c:0, e:0]
# T=1092.55, clienteE36: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE36: 217.56
# T=1093.87 clienteC37: COLA COMERCIAL - llegue con un IA:  1.33
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# T=1093.87, clienteC37: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC37: 175.24
# T=1113.71, clienteC28: Sali de un puesto comercial
# T=1123.88 clienteC38: COLA COMERCIAL - llegue con un IA: 30.01
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# T=1123.88, clienteC38: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC38: 156.87
# T=1130.56 clienteC39: COLA COMERCIAL - llegue con un IA:  6.68
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# T=1130.56, clienteC39: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC39: 294.91
# T=1137.19, clienteC35: Sali de un puesto comercial
# T=1137.91, clienteC22: Sali de un puesto comercial
# T=1143.07, clienteC23: Sali de un puesto comercial
# T=1164.01, clienteC30: Sali de un puesto comercial
# T=1165.79, clienteE34: Sali de un puesto de emergencia
# T=1186.43 clienteC40: COLA COMERCIAL - llegue con un IA: 55.88
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1186.43, clienteC40: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC40: 87.05
# T=1219.59 clienteC41: COLA COMERCIAL - llegue con un IA: 33.15
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# T=1219.59, clienteC41: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC41: 259.76
# T=1268.28 clienteC42: COLA COMERCIAL - llegue con un IA: 48.69
# Atendiendo:[c:12, e:4]
# En cola:[c:0, e:0]
# T=1268.28, clienteC42: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC42: 79.12
# T=1269.12, clienteC37: Sali de un puesto comercial
# T=1273.49, clienteC40: Sali de un puesto comercial
# T=1280.75, clienteC38: Sali de un puesto comercial
# T=1295.90 clienteC43: COLA COMERCIAL - llegue con un IA: 27.62
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1295.90, clienteC43: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC43: 602.61
# T=1307.16, clienteC27: Sali de un puesto comercial
# T=1310.11, clienteE36: Sali de un puesto de emergencia
# T=1328.58 clienteC44: COLA COMERCIAL - llegue con un IA: 32.68
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1328.58, clienteC44: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC44: 88.61
# T=1347.40, clienteC42: Sali de un puesto comercial
# T=1386.40 clienteC45: COLA COMERCIAL - llegue con un IA: 57.83
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1386.40, clienteC45: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC45: 481.07
# T=1387.68, clienteC33: Sali de un puesto comercial
# T=1401.27 clienteE46: COLA EMERGENCIA - llegue con un IA: 14.87
# Atendiendo:[c:10, e:4]
# En cola:[c:0, e:0]
# T=1401.27, clienteE46: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:11, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE46: 72.63
# T=1411.16, clienteC31: Sali de un puesto comercial
# T=1417.19, clienteC44: Sali de un puesto comercial
# T=1425.46, clienteC39: Sali de un puesto comercial
# T=1433.81 clienteC47: COLA COMERCIAL - llegue con un IA: 32.54
# Atendiendo:[c:8, e:5]
# En cola:[c:0, e:0]
# T=1433.81, clienteC47: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:9, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC47: 411.81
# T=1473.90, clienteE46: Sali de un puesto de emergencia
# T=1478.86 clienteC48: COLA COMERCIAL - llegue con un IA: 45.05
# Atendiendo:[c:9, e:5]
# En cola:[c:0, e:0]
# T=1478.86, clienteC48: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC48: 169.72
# T=1479.35, clienteC41: Sali de un puesto comercial
# T=1484.76 clienteC49: COLA COMERCIAL - llegue con un IA:  5.90
# Atendiendo:[c:9, e:5]
# En cola:[c:0, e:0]
# T=1484.76, clienteC49: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:10, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC49: 178.43
# T=1520.32 clienteC50: COLA COMERCIAL - llegue con un IA: 35.56
# Atendiendo:[c:10, e:5]
# En cola:[c:0, e:0]
# T=1520.32, clienteC50: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC50: 422.20
# T=1546.40 clienteC51: COLA COMERCIAL - llegue con un IA: 26.08
# Atendiendo:[c:11, e:5]
# En cola:[c:0, e:0]
# T=1546.40, clienteC51: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC51: 580.85
# T=1576.49 clienteC52: COLA COMERCIAL - llegue con un IA: 30.10
# Atendiendo:[c:12, e:5]
# En cola:[c:0, e:0]
# T=1576.49, clienteC52: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC52: 53.81
# T=1589.32 clienteC53: COLA COMERCIAL - llegue con un IA: 12.82
# Atendiendo:[c:13, e:5]
# En cola:[c:0, e:0]
# T=1589.32, clienteC53: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC53: 568.56
# T=1630.30, clienteC52: Sali de un puesto comercial
# T=1637.73 clienteC54: COLA COMERCIAL - llegue con un IA: 48.41
# Atendiendo:[c:13, e:5]
# En cola:[c:0, e:0]
# T=1637.73, clienteC54: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC54: 195.22
# T=1648.58, clienteC48: Sali de un puesto comercial
# T=1663.18, clienteC49: Sali de un puesto comercial
# T=1686.08 clienteC55: COLA COMERCIAL - llegue con un IA: 48.35
# Atendiendo:[c:12, e:5]
# En cola:[c:0, e:0]
# T=1686.08, clienteC55: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC55: 228.12
# T=1736.75 clienteE56: COLA EMERGENCIA - llegue con un IA: 50.67
# Atendiendo:[c:13, e:5]
# En cola:[c:0, e:0]
# T=1736.75, clienteE56: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE56: 460.00
# T=1754.77 clienteC57: COLA COMERCIAL - llegue con un IA: 18.02
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=1754.77, clienteC57: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC57: 259.46
# T=1778.55 clienteC58: COLA COMERCIAL - llegue con un IA: 23.78
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=1778.55, clienteC58: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC58: 11.60
# T=1789.01 clienteC59: COLA COMERCIAL - llegue con un IA: 10.46
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# T=1789.01, clienteC59: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC59: 277.38
# T=1790.16, clienteC58: Sali de un puesto comercial
# T=1832.95, clienteC54: Sali de un puesto comercial
# T=1834.62 clienteC60: COLA COMERCIAL - llegue con un IA: 45.61
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=1834.62, clienteC60: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC60: 142.16
# T=1845.62, clienteC47: Sali de un puesto comercial
# T=1867.48, clienteC45: Sali de un puesto comercial
# T=1884.35 clienteC61: COLA COMERCIAL - llegue con un IA: 49.72
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=1884.35, clienteC61: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC61: 235.52
# T=1898.51, clienteC43: Sali de un puesto comercial
# T=1909.60 clienteC62: COLA COMERCIAL - llegue con un IA: 25.25
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=1909.60, clienteC62: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC62: 249.31
# T=1914.20, clienteC55: Sali de un puesto comercial
# T=1939.21 clienteC63: COLA COMERCIAL - llegue con un IA: 29.61
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=1939.21, clienteC63: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC63: 77.12
# T=1942.52, clienteC50: Sali de un puesto comercial
# T=1943.78 clienteC64: COLA COMERCIAL - llegue con un IA:  4.57
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=1943.78, clienteC64: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC64: 357.78
# T=1962.25 clienteC65: COLA COMERCIAL - llegue con un IA: 18.47
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=1962.25, clienteC65: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC65: 217.39
# T=1976.78, clienteC60: Sali de un puesto comercial
# T=1979.74 clienteC66: COLA COMERCIAL - llegue con un IA: 17.49
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=1979.74, clienteC66: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC66: 282.90
# T=1993.99 clienteC67: COLA COMERCIAL - llegue con un IA: 14.26
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# T=1993.99, clienteC67: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC67: 341.89
# T=2014.23, clienteC57: Sali de un puesto comercial
# T=2016.32, clienteC63: Sali de un puesto comercial
# T=2049.52 clienteC68: COLA COMERCIAL - llegue con un IA: 55.52
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=2049.52, clienteC68: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC68: 78.47
# T=2066.39, clienteC59: Sali de un puesto comercial
# T=2097.09 clienteC69: COLA COMERCIAL - llegue con un IA: 47.57
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=2097.09, clienteC69: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC69: 367.02
# T=2116.40 clienteC70: COLA COMERCIAL - llegue con un IA: 19.31
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# T=2116.40, clienteC70: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC70: 207.69
# T=2119.87, clienteC61: Sali de un puesto comercial
# T=2127.25, clienteC51: Sali de un puesto comercial
# T=2127.99, clienteC68: Sali de un puesto comercial
# T=2157.87, clienteC53: Sali de un puesto comercial
# T=2158.90, clienteC62: Sali de un puesto comercial
# T=2162.27 clienteC71: COLA COMERCIAL - llegue con un IA: 45.87
# Atendiendo:[c:12, e:6]
# En cola:[c:0, e:0]
# T=2162.27, clienteC71: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC71: 403.18
# T=2165.19 clienteC72: COLA COMERCIAL - llegue con un IA:  2.91
# Atendiendo:[c:13, e:6]
# En cola:[c:0, e:0]
# T=2165.19, clienteC72: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC72: 335.62
# T=2166.31 clienteC73: COLA COMERCIAL - llegue con un IA:  1.13
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=2166.31, clienteC73: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC73: 44.24
# T=2179.63, clienteC65: Sali de un puesto comercial
# T=2180.77 clienteC74: COLA COMERCIAL - llegue con un IA: 14.46
# Atendiendo:[c:14, e:6]
# En cola:[c:0, e:0]
# T=2180.77, clienteC74: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC74: 406.66
# T=2196.76, clienteE56: Sali de un puesto de emergencia
# T=2209.82 clienteC75: COLA COMERCIAL - llegue con un IA: 29.05
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=2209.82, clienteC75: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC75: 66.49
# T=2210.56, clienteC73: Sali de un puesto comercial
# T=2221.97 clienteC76: COLA COMERCIAL - llegue con un IA: 12.15
# Atendiendo:[c:15, e:6]
# En cola:[c:0, e:0]
# T=2221.97, clienteC76: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC76: 154.24
# T=2259.32 clienteE77: COLA EMERGENCIA - llegue con un IA: 37.35
# Atendiendo:[c:16, e:6]
# En cola:[c:0, e:0]
# T=2259.32, clienteE77: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:17, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE77: 374.86
# T=2262.63, clienteC66: Sali de un puesto comercial
# T=2276.31, clienteC75: Sali de un puesto comercial
# T=2301.55 clienteC78: COLA COMERCIAL - llegue con un IA: 42.23
# Atendiendo:[c:15, e:7]
# En cola:[c:0, e:0]
# T=2301.55, clienteC78: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC78: 288.99
# T=2301.56, clienteC64: Sali de un puesto comercial
# T=2324.09, clienteC70: Sali de un puesto comercial
# T=2330.23 clienteC79: COLA COMERCIAL - llegue con un IA: 28.68
# Atendiendo:[c:14, e:7]
# En cola:[c:0, e:0]
# T=2330.23, clienteC79: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC79: 138.75
# T=2335.89, clienteC67: Sali de un puesto comercial
# T=2371.31 clienteC80: COLA COMERCIAL - llegue con un IA: 41.08
# Atendiendo:[c:14, e:7]
# En cola:[c:0, e:0]
# T=2371.31, clienteC80: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC80: 492.33
# T=2376.21, clienteC76: Sali de un puesto comercial
# T=2420.62 clienteC81: COLA COMERCIAL - llegue con un IA: 49.31
# Atendiendo:[c:14, e:7]
# En cola:[c:0, e:0]
# T=2420.62, clienteC81: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC81: 74.71
# T=2463.68 clienteC82: COLA COMERCIAL - llegue con un IA: 43.06
# Atendiendo:[c:15, e:7]
# En cola:[c:0, e:0]
# T=2463.68, clienteC82: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC82: 233.22
# T=2464.11, clienteC69: Sali de un puesto comercial
# T=2468.98, clienteC79: Sali de un puesto comercial
# T=2495.33, clienteC81: Sali de un puesto comercial
# T=2500.81, clienteC72: Sali de un puesto comercial
# T=2506.34 clienteC83: COLA COMERCIAL - llegue con un IA: 42.66
# Atendiendo:[c:12, e:7]
# En cola:[c:0, e:0]
# T=2506.34, clienteC83: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC83: 212.01
# T=2556.09 clienteC84: COLA COMERCIAL - llegue con un IA: 49.75
# Atendiendo:[c:13, e:7]
# En cola:[c:0, e:0]
# T=2556.09, clienteC84: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC84: 27.84
# T=2565.46, clienteC71: Sali de un puesto comercial
# T=2583.93, clienteC84: Sali de un puesto comercial
# T=2587.44, clienteC74: Sali de un puesto comercial
# T=2590.54, clienteC78: Sali de un puesto comercial
# T=2595.23 clienteC85: COLA COMERCIAL - llegue con un IA: 39.15
# Atendiendo:[c:10, e:7]
# En cola:[c:0, e:0]
# T=2595.23, clienteC85: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC85:  8.46
# T=2603.69, clienteC85: Sali de un puesto comercial
# T=2614.88 clienteC86: COLA COMERCIAL - llegue con un IA: 19.65
# Atendiendo:[c:10, e:7]
# En cola:[c:0, e:0]
# T=2614.88, clienteC86: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:7]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC86: 94.05
# T=2634.18, clienteE77: Sali de un puesto de emergencia
# T=2673.60 clienteE87: COLA EMERGENCIA - llegue con un IA: 58.72
# Atendiendo:[c:11, e:7]
# En cola:[c:0, e:0]
# T=2673.60, clienteE87: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE87: 399.57
# T=2692.26 clienteC88: COLA COMERCIAL - llegue con un IA: 18.66
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# T=2692.26, clienteC88: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC88: 46.30
# T=2696.90, clienteC82: Sali de un puesto comercial
# T=2708.93, clienteC86: Sali de un puesto comercial
# T=2718.35, clienteC83: Sali de un puesto comercial
# T=2726.14 clienteC89: COLA COMERCIAL - llegue con un IA: 33.89
# Atendiendo:[c:10, e:8]
# En cola:[c:0, e:0]
# T=2726.14, clienteC89: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:11, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC89: 126.60
# T=2735.06 clienteC90: COLA COMERCIAL - llegue con un IA:  8.91
# Atendiendo:[c:11, e:8]
# En cola:[c:0, e:0]
# T=2735.06, clienteC90: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC90: 501.98
# T=2738.56, clienteC88: Sali de un puesto comercial
# T=2767.44 clienteC91: COLA COMERCIAL - llegue con un IA: 32.38
# Atendiendo:[c:11, e:8]
# En cola:[c:0, e:0]
# T=2767.44, clienteC91: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC91: 488.67
# T=2804.91 clienteC92: COLA COMERCIAL - llegue con un IA: 37.47
# Atendiendo:[c:12, e:8]
# En cola:[c:0, e:0]
# T=2804.91, clienteC92: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC92: 52.21
# T=2841.24 clienteC93: COLA COMERCIAL - llegue con un IA: 36.33
# Atendiendo:[c:13, e:8]
# En cola:[c:0, e:0]
# T=2841.24, clienteC93: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:8]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC93: 21.01
# T=2852.74, clienteC89: Sali de un puesto comercial
# T=2857.11, clienteC92: Sali de un puesto comercial
# T=2862.25, clienteC93: Sali de un puesto comercial
# T=2863.64, clienteC80: Sali de un puesto comercial
# T=2885.49 clienteE94: COLA EMERGENCIA - llegue con un IA: 44.25
# Atendiendo:[c:10, e:8]
# En cola:[c:0, e:0]
# T=2885.49, clienteE94: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:11, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE94: 133.87
# T=2935.84 clienteC95: COLA COMERCIAL - llegue con un IA: 50.34
# Atendiendo:[c:11, e:9]
# En cola:[c:0, e:0]
# T=2935.84, clienteC95: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC95: 29.54
# T=2965.38, clienteC95: Sali de un puesto comercial
# T=2995.73 clienteC96: COLA COMERCIAL - llegue con un IA: 59.89
# Atendiendo:[c:11, e:9]
# En cola:[c:0, e:0]
# T=2995.73, clienteC96: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:12, e:9]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC96: 570.45
# T=3019.37, clienteE94: Sali de un puesto de emergencia
# T=3026.41 clienteE97: COLA EMERGENCIA - llegue con un IA: 30.69
# Atendiendo:[c:12, e:9]
# En cola:[c:0, e:0]
# T=3026.41, clienteE97: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:13, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE97: 448.94
# T=3073.17, clienteE87: Sali de un puesto de emergencia
# T=3075.69 clienteC98: COLA COMERCIAL - llegue con un IA: 49.28
# Atendiendo:[c:13, e:10]
# En cola:[c:0, e:0]
# T=3075.69, clienteC98: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:14, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC98: 61.12
# T=3081.23 clienteC99: COLA COMERCIAL - llegue con un IA:  5.53
# Atendiendo:[c:14, e:10]
# En cola:[c:0, e:0]
# T=3081.23, clienteC99: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:15, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC99: 352.60
# T=3127.23 clienteC100: COLA COMERCIAL - llegue con un IA: 46.00
# Atendiendo:[c:15, e:10]
# En cola:[c:0, e:0]
# T=3127.23, clienteC100: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC100: 281.04
# T=3136.82, clienteC98: Sali de un puesto comercial
# T=3147.89 clienteC101: COLA COMERCIAL - llegue con un IA: 20.66
# Atendiendo:[c:15, e:10]
# En cola:[c:0, e:0]
# T=3147.89, clienteC101: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC101: 273.55
# T=3180.09 clienteC102: COLA COMERCIAL - llegue con un IA: 32.20
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# T=3180.09, clienteC102: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC102: 40.77
# T=3220.85, clienteC102: Sali de un puesto comercial
# T=3231.49 clienteC103: COLA COMERCIAL - llegue con un IA: 51.41
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# T=3231.49, clienteC103: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC103: 193.01
# T=3237.04, clienteC90: Sali de un puesto comercial
# T=3249.17 clienteC104: COLA COMERCIAL - llegue con un IA: 17.67
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# T=3249.17, clienteC104: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:10]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC104: 203.17
# T=3256.11, clienteC91: Sali de un puesto comercial
# T=3271.90 clienteE105: COLA EMERGENCIA - llegue con un IA: 22.73
# Atendiendo:[c:16, e:10]
# En cola:[c:0, e:0]
# T=3271.90, clienteE105: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE105: 364.07
# T=3286.29 clienteC106: COLA COMERCIAL - llegue con un IA: 14.39
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# T=3286.29, clienteC106: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC106: 48.11
# T=3334.40, clienteC106: Sali de un puesto comercial
# T=3338.20 clienteC107: COLA COMERCIAL - llegue con un IA: 51.91
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# T=3338.20, clienteC107: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC107: 264.76
# T=3347.19 clienteC108: COLA COMERCIAL - llegue con un IA:  8.99
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# T=3347.19, clienteC108: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC108: 223.07
# T=3392.05 clienteC109: COLA COMERCIAL - llegue con un IA: 44.86
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# T=3392.05, clienteC109: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:20, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC109: 65.94
# T=3408.27, clienteC100: Sali de un puesto comercial
# T=3414.94 clienteC110: COLA COMERCIAL - llegue con un IA: 22.89
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# T=3414.94, clienteC110: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:20, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC110: 257.29
# T=3421.44, clienteC101: Sali de un puesto comercial
# T=3424.50, clienteC103: Sali de un puesto comercial
# T=3433.83, clienteC99: Sali de un puesto comercial
# T=3452.33, clienteC104: Sali de un puesto comercial
# T=3457.99, clienteC109: Sali de un puesto comercial
# T=3473.01 clienteC111: COLA COMERCIAL - llegue con un IA: 58.07
# Atendiendo:[c:15, e:11]
# En cola:[c:0, e:0]
# T=3473.01, clienteC111: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:16, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC111: 190.83
# T=3475.35, clienteE97: Sali de un puesto de emergencia
# T=3514.93 clienteC112: COLA COMERCIAL - llegue con un IA: 41.93
# Atendiendo:[c:16, e:11]
# En cola:[c:0, e:0]
# T=3514.93, clienteC112: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC112: 384.70
# T=3521.02 clienteC113: COLA COMERCIAL - llegue con un IA:  6.08
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# T=3521.02, clienteC113: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC113: 610.69
# T=3548.46 clienteC114: COLA COMERCIAL - llegue con un IA: 27.44
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# T=3548.46, clienteC114: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC114: 430.64
# T=3566.18, clienteC96: Sali de un puesto comercial
# T=3570.26, clienteC108: Sali de un puesto comercial
# T=3588.85 clienteC115: COLA COMERCIAL - llegue con un IA: 40.39
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# T=3588.85, clienteC115: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC115: 379.27
# T=3592.06 clienteC116: COLA COMERCIAL - llegue con un IA:  3.22
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# T=3592.06, clienteC116: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC116: 20.93
# T=3602.97, clienteC107: Sali de un puesto comercial
# T=3613.00, clienteC116: Sali de un puesto comercial
# T=3635.97, clienteE105: Sali de un puesto de emergencia
# T=3649.64 clienteC117: COLA COMERCIAL - llegue con un IA: 57.58
# Atendiendo:[c:17, e:11]
# En cola:[c:0, e:0]
# T=3649.64, clienteC117: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC117: 184.88
# T=3652.61 clienteC118: COLA COMERCIAL - llegue con un IA:  2.97
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# T=3652.61, clienteC118: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC118: 119.32
# T=3663.84, clienteC111: Sali de un puesto comercial
# T=3666.91 clienteC119: COLA COMERCIAL - llegue con un IA: 14.30
# Atendiendo:[c:18, e:11]
# En cola:[c:0, e:0]
# T=3666.91, clienteC119: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC119: 197.41
# T=3670.94 clienteC120: COLA COMERCIAL - llegue con un IA:  4.04
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# T=3670.94, clienteC120: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:20, e:11]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC120: 273.87
# T=3672.23, clienteC110: Sali de un puesto comercial
# T=3698.59 clienteE121: COLA EMERGENCIA - llegue con un IA: 27.65
# Atendiendo:[c:19, e:11]
# En cola:[c:0, e:0]
# T=3698.59, clienteE121: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:20, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE121: 67.25
# T=3736.66 clienteC122: COLA COMERCIAL - llegue con un IA: 38.07
# Atendiendo:[c:20, e:12]
# En cola:[c:0, e:0]
# T=3736.66, clienteC122: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC122: 600.75
# T=3738.85 clienteC123: COLA COMERCIAL - llegue con un IA:  2.19
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# T=3738.85, clienteC123: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC123: 137.82
# T=3765.84, clienteE121: Sali de un puesto de emergencia
# T=3771.93, clienteC118: Sali de un puesto comercial
# T=3791.98 clienteC124: COLA COMERCIAL - llegue con un IA: 53.12
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# T=3791.98, clienteC124: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC124: 212.86
# T=3817.21 clienteC125: COLA COMERCIAL - llegue con un IA: 25.23
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# T=3817.21, clienteC125: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC125: 292.87
# T=3834.52, clienteC117: Sali de un puesto comercial
# T=3864.32, clienteC119: Sali de un puesto comercial
# T=3876.43 clienteC126: COLA COMERCIAL - llegue con un IA: 59.22
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# T=3876.43, clienteC126: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC126: 270.38
# T=3876.67, clienteC123: Sali de un puesto comercial
# T=3899.63, clienteC112: Sali de un puesto comercial
# T=3912.75 clienteC127: COLA COMERCIAL - llegue con un IA: 36.33
# Atendiendo:[c:20, e:12]
# En cola:[c:0, e:0]
# T=3912.75, clienteC127: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC127: 149.27
# T=3928.01 clienteC128: COLA COMERCIAL - llegue con un IA: 15.25
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# T=3928.01, clienteC128: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC128: 21.67
# T=3933.75 clienteC129: COLA COMERCIAL - llegue con un IA:  5.75
# Atendiendo:[c:22, e:12]
# En cola:[c:0, e:0]
# T=3933.75, clienteC129: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC129: 295.73
# T=3944.81, clienteC120: Sali de un puesto comercial
# T=3949.68, clienteC128: Sali de un puesto comercial
# T=3968.12, clienteC115: Sali de un puesto comercial
# T=3978.96 clienteC130: COLA COMERCIAL - llegue con un IA: 45.20
# Atendiendo:[c:20, e:12]
# En cola:[c:0, e:0]
# T=3978.96, clienteC130: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:12]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC130: 61.49
# T=3979.10, clienteC114: Sali de un puesto comercial
# T=4004.83, clienteC124: Sali de un puesto comercial
# T=4010.52 clienteE131: COLA EMERGENCIA - llegue con un IA: 31.57
# Atendiendo:[c:19, e:12]
# En cola:[c:0, e:0]
# T=4010.52, clienteE131: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE131: 45.02
# T=4039.19 clienteC132: COLA COMERCIAL - llegue con un IA: 28.66
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=4039.19, clienteC132: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC132: 206.99
# T=4040.45, clienteC130: Sali de un puesto comercial
# T=4043.60 clienteC133: COLA COMERCIAL - llegue con un IA:  4.41
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=4043.60, clienteC133: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC133: 102.18
# T=4055.54, clienteE131: Sali de un puesto de emergencia
# T=4057.12 clienteC134: COLA COMERCIAL - llegue con un IA: 13.52
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# T=4057.12, clienteC134: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC134: 221.73
# T=4062.02, clienteC127: Sali de un puesto comercial
# T=4072.54 clienteC135: COLA COMERCIAL - llegue con un IA: 15.41
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# T=4072.54, clienteC135: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC135: 45.46
# T=4101.57 clienteC136: COLA COMERCIAL - llegue con un IA: 29.03
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# T=4101.57, clienteC136: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC136: 218.30
# T=4110.08, clienteC125: Sali de un puesto comercial
# T=4116.22 clienteC137: COLA COMERCIAL - llegue con un IA: 14.64
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# T=4116.22, clienteC137: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:23, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC137: 289.42
# T=4117.67 clienteC138: COLA COMERCIAL - llegue con un IA:  1.46
# Atendiendo:[c:23, e:13]
# En cola:[c:0, e:0]
# T=4117.67, clienteC138: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:24, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC138: 206.24
# T=4117.99, clienteC135: Sali de un puesto comercial
# T=4131.70, clienteC113: Sali de un puesto comercial
# T=4145.78, clienteC133: Sali de un puesto comercial
# T=4146.80, clienteC126: Sali de un puesto comercial
# T=4156.41 clienteC139: COLA COMERCIAL - llegue con un IA: 38.74
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=4156.41, clienteC139: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC139: 166.89
# T=4205.59 clienteC140: COLA COMERCIAL - llegue con un IA: 49.18
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# T=4205.59, clienteC140: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC140: 443.61
# T=4229.49, clienteC129: Sali de un puesto comercial
# T=4246.18, clienteC132: Sali de un puesto comercial
# T=4264.53 clienteC141: COLA COMERCIAL - llegue con un IA: 58.95
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=4264.53, clienteC141: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:21, e:13]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC141: 66.51
# T=4278.86, clienteC134: Sali de un puesto comercial
# T=4283.81 clienteE142: COLA EMERGENCIA - llegue con un IA: 19.27
# Atendiendo:[c:20, e:13]
# En cola:[c:0, e:0]
# T=4283.81, clienteE142: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:21, e:14]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE142: 574.14
# T=4308.38 clienteC143: COLA COMERCIAL - llegue con un IA: 24.58
# Atendiendo:[c:21, e:14]
# En cola:[c:0, e:0]
# T=4308.38, clienteC143: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:22, e:14]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC143: 491.36
# T=4319.87, clienteC136: Sali de un puesto comercial
# T=4323.30, clienteC139: Sali de un puesto comercial
# T=4323.91, clienteC138: Sali de un puesto comercial
# T=4331.04, clienteC141: Sali de un puesto comercial
# T=4337.41, clienteC122: Sali de un puesto comercial
# T=4346.83 clienteC144: COLA COMERCIAL - llegue con un IA: 38.45
# Atendiendo:[c:17, e:14]
# En cola:[c:0, e:0]
# T=4346.83, clienteC144: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:18, e:14]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC144: 410.31
# T=4381.63 clienteC145: COLA COMERCIAL - llegue con un IA: 34.80
# Atendiendo:[c:18, e:14]
# En cola:[c:0, e:0]
# T=4381.63, clienteC145: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:19, e:14]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC145: 202.33
# T=4405.64, clienteC137: Sali de un puesto comercial
# T=4414.37 clienteC146: COLA COMERCIAL - llegue con un IA: 32.75
# ...
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:32]
# T=12359.86, clienteC410: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC410: 102.55
# T=12372.38, clienteC408: Sali de un puesto comercial
# T=12403.06 clienteC411: COLA COMERCIAL - llegue con un IA: 43.20
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:32]
# T=12403.06, clienteC411: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC411: 175.23
# T=12411.19 clienteC412: COLA COMERCIAL - llegue con un IA:  8.13
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# T=12411.19, clienteC412: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC412: 93.73
# T=12413.84, clienteC406: Sali de un puesto comercial
# T=12419.65 clienteC413: COLA COMERCIAL - llegue con un IA:  8.46
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# T=12419.65, clienteC413: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC413: 354.33
# T=12455.50, clienteC396: Sali de un puesto comercial
# T=12462.40, clienteC410: Sali de un puesto comercial
# T=12473.40 clienteC414: COLA COMERCIAL - llegue con un IA: 53.75
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:32]
# T=12473.40, clienteC414: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC414: 457.97
# T=12481.70 clienteC415: COLA COMERCIAL - llegue con un IA:  8.30
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:32]
# T=12481.70, clienteC415: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:32]
# Tiempo de Atencion generado para clienteC415: 68.87
# T=12489.60, clienteC407: Sali de un puesto comercial
# T=12504.92, clienteC412: Sali de un puesto comercial
# T=12541.32 clienteE416: COLA EMERGENCIA - llegue con un IA: 59.62
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:32]
# T=12541.32, clienteE416: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteE416:  5.71
# T=12547.03, clienteE416: Sali de un puesto de emergencia
# T=12550.57, clienteC415: Sali de un puesto comercial
# T=12578.28, clienteC411: Sali de un puesto comercial
# T=12586.50 clienteC417: COLA COMERCIAL - llegue con un IA: 45.18
# Atendiendo:[c:57, e:20]
# En cola:[c:0, e:33]
# T=12586.50, clienteC417: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC417: 251.11
# T=12605.92 clienteC418: COLA COMERCIAL - llegue con un IA: 19.42
# Atendiendo:[c:58, e:20]
# En cola:[c:0, e:33]
# T=12605.92, clienteC418: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC418: 113.50
# T=12619.39 clienteC419: COLA COMERCIAL - llegue con un IA: 13.48
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:33]
# T=12619.39, clienteC419: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC419: 16.18
# T=12627.46 clienteC420: COLA COMERCIAL - llegue con un IA:  8.07
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# T=12631.36 clienteC421: COLA COMERCIAL - llegue con un IA:  3.90
# Atendiendo:[c:60, e:20]
# En cola:[c:1, e:33]
# T=12635.57, clienteC419: Sali de un puesto comercial
# T=12635.57, clienteC420: COLA COMERCIAL - Me atendieron despues de esperar  8.11
# Atendiendo:[c:60, e:20]
# En cola:[c:1, e:33]
# Tiempo de Atencion generado para clienteC420: 550.83
# T=12654.12, clienteC405: Sali de un puesto comercial
# T=12654.12, clienteC421: COLA COMERCIAL - Me atendieron despues de esperar 22.77
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC421: 456.05
# T=12689.70 clienteC422: COLA COMERCIAL - llegue con un IA: 58.35
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# T=12716.51, clienteC409: Sali de un puesto comercial
# T=12716.51, clienteC422: COLA COMERCIAL - Me atendieron despues de esperar 26.80
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC422: 365.51
# T=12719.42, clienteC418: Sali de un puesto comercial
# T=12731.17 clienteC423: COLA COMERCIAL - llegue con un IA: 41.46
# Atendiendo:[c:59, e:20]
# En cola:[c:0, e:33]
# T=12731.17, clienteC423: COLA COMERCIAL - Me atendieron despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# Tiempo de Atencion generado para clienteC423: 182.49
# T=12732.87 clienteC424: COLA COMERCIAL - llegue con un IA:  1.70
# Atendiendo:[c:60, e:20]
# En cola:[c:0, e:33]
# T=12757.63 clienteE425: COLA EMERGENCIA - llegue con un IA: 24.76
# Atendiendo:[c:60, e:20]
# En cola:[c:1, e:33]
# T=12770.13 clienteC426: COLA COMERCIAL - llegue con un IA: 12.50
# Atendiendo:[c:60, e:20]
# En cola:[c:2, e:34]
# T=12773.24 clienteC427: COLA COMERCIAL - llegue con un IA:  3.11
# Atendiendo:[c:60, e:20]
# En cola:[c:3, e:34]
# T=12773.97, clienteC413: Sali de un puesto comercial
# T=12773.97, clienteE425: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 16.35
# Atendiendo:[c:60, e:20]
# En cola:[c:3, e:34]
# Tiempo de Atencion generado para clienteE425: 210.07
# T=12811.48 clienteE428: COLA EMERGENCIA - llegue con un IA: 38.24
# Atendiendo:[c:60, e:20]
# En cola:[c:3, e:34]
# T=12833.47 clienteE429: COLA EMERGENCIA - llegue con un IA: 21.99
# Atendiendo:[c:60, e:20]
# En cola:[c:4, e:35]
# T=12837.61, clienteC417: Sali de un puesto comercial
# T=12837.61, clienteE428: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 26.13
# Atendiendo:[c:60, e:20]
# En cola:[c:4, e:36]
# Tiempo de Atencion generado para clienteE428: 336.41
# T=12868.50 clienteC430: COLA COMERCIAL - llegue con un IA: 35.03
# Atendiendo:[c:60, e:20]
# En cola:[c:4, e:36]
# T=12871.44 clienteC431: COLA COMERCIAL - llegue con un IA:  2.94
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# T=12913.65, clienteC423: Sali de un puesto comercial
# T=12913.65, clienteE429: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 80.19
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# Tiempo de Atencion generado para clienteE429: 429.44
# T=12926.84 clienteC432: COLA COMERCIAL - llegue con un IA: 55.40
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# T=12931.36, clienteC414: Sali de un puesto comercial
# T=12931.36, clienteC424: COLA COMERCIAL - Me atendieron despues de esperar 198.50
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# Tiempo de Atencion generado para clienteC424: 10.85
# T=12942.22, clienteC424: Sali de un puesto comercial
# T=12942.22, clienteC426: COLA COMERCIAL - Me atendieron despues de esperar 172.08
# Atendiendo:[c:60, e:20]
# En cola:[c:4, e:36]
# Tiempo de Atencion generado para clienteC426: 158.49
# T=12967.79 clienteC433: COLA COMERCIAL - llegue con un IA: 40.95
# Atendiendo:[c:60, e:20]
# En cola:[c:4, e:36]
# T=12984.05, clienteE425: Sali de un puesto de emergencia
# T=13026.47 clienteC434: COLA COMERCIAL - llegue con un IA: 58.68
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# T=13078.24 clienteC435: COLA COMERCIAL - llegue con un IA: 51.78
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# T=13082.01, clienteC422: Sali de un puesto comercial
# T=13082.01, clienteC427: COLA COMERCIAL - Me atendieron despues de esperar 308.77
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# Tiempo de Atencion generado para clienteC427: 232.54
# T=13088.94 clienteC436: COLA COMERCIAL - llegue con un IA: 10.69
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# T=13100.71, clienteC426: Sali de un puesto comercial
# T=13100.71, clienteC430: COLA COMERCIAL - Me atendieron despues de esperar 232.21
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# Tiempo de Atencion generado para clienteC430: 89.89
# T=13110.17, clienteC421: Sali de un puesto comercial
# T=13110.17, clienteC431: COLA COMERCIAL - Me atendieron despues de esperar 238.73
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# Tiempo de Atencion generado para clienteC431: 47.25
# T=13123.63 clienteC437: COLA COMERCIAL - llegue con un IA: 34.69
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# T=13147.17 clienteC438: COLA COMERCIAL - llegue con un IA: 23.54
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# T=13157.41, clienteC431: Sali de un puesto comercial
# T=13157.41, clienteC432: COLA COMERCIAL - Me atendieron despues de esperar 230.57
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# Tiempo de Atencion generado para clienteC432: 594.01
# T=13174.02, clienteE428: Sali de un puesto de emergencia
# T=13183.38 clienteC439: COLA COMERCIAL - llegue con un IA: 36.21
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# T=13186.40, clienteC420: Sali de un puesto comercial
# T=13186.40, clienteC433: COLA COMERCIAL - Me atendieron despues de esperar 218.61
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# Tiempo de Atencion generado para clienteC433: 571.77
# T=13190.60, clienteC430: Sali de un puesto comercial
# T=13190.60, clienteC434: COLA COMERCIAL - Me atendieron despues de esperar 164.13
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# Tiempo de Atencion generado para clienteC434: 213.28
# T=13235.22 clienteC440: COLA COMERCIAL - llegue con un IA: 51.84
# Atendiendo:[c:60, e:20]
# En cola:[c:5, e:36]
# T=13253.91 clienteC441: COLA COMERCIAL - llegue con un IA: 18.69
# Atendiendo:[c:60, e:20]
# En cola:[c:6, e:36]
# T=13266.93 clienteC442: COLA COMERCIAL - llegue con un IA: 13.01
# Atendiendo:[c:60, e:20]
# En cola:[c:7, e:36]
# T=13271.02 clienteC443: COLA COMERCIAL - llegue con un IA:  4.09
# Atendiendo:[c:60, e:20]
# En cola:[c:8, e:36]
# T=13311.10 clienteC444: COLA COMERCIAL - llegue con un IA: 40.09
# Atendiendo:[c:60, e:20]
# En cola:[c:9, e:36]
# T=13314.56, clienteC427: Sali de un puesto comercial
# T=13314.56, clienteC435: COLA COMERCIAL - Me atendieron despues de esperar 236.31
# Atendiendo:[c:60, e:20]
# En cola:[c:9, e:36]
# Tiempo de Atencion generado para clienteC435: 492.85
# T=13319.82 clienteE445: COLA EMERGENCIA - llegue con un IA:  8.71
# Atendiendo:[c:60, e:20]
# En cola:[c:9, e:36]
# T=13326.15 clienteC446: COLA COMERCIAL - llegue con un IA:  6.33
# Atendiendo:[c:60, e:20]
# En cola:[c:10, e:37]
# T=13328.66 clienteC447: COLA COMERCIAL - llegue con un IA:  2.51
# Atendiendo:[c:60, e:20]
# En cola:[c:11, e:37]
# T=13343.09, clienteE429: Sali de un puesto de emergencia
# T=13346.38 clienteE448: COLA EMERGENCIA - llegue con un IA: 17.72
# Atendiendo:[c:60, e:20]
# En cola:[c:12, e:37]
# T=13370.73 clienteC449: COLA COMERCIAL - llegue con un IA: 24.35
# Atendiendo:[c:60, e:20]
# En cola:[c:13, e:38]
# T=13381.82 clienteC450: COLA COMERCIAL - llegue con un IA: 11.08
# Atendiendo:[c:60, e:20]
# En cola:[c:14, e:38]
# T=13387.74 clienteE451: COLA EMERGENCIA - llegue con un IA:  5.92
# Atendiendo:[c:60, e:20]
# En cola:[c:15, e:38]
# T=13394.17 clienteC452: COLA COMERCIAL - llegue con un IA:  6.44
# Atendiendo:[c:60, e:20]
# En cola:[c:16, e:39]
# T=13403.89, clienteC434: Sali de un puesto comercial
# T=13403.89, clienteE445: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 84.07
# Atendiendo:[c:60, e:20]
# En cola:[c:16, e:39]
# Tiempo de Atencion generado para clienteE445: 61.50
# T=13448.52 clienteC453: COLA COMERCIAL - llegue con un IA: 54.34
# Atendiendo:[c:60, e:20]
# En cola:[c:16, e:39]
# T=13465.38, clienteE445: Sali de un puesto de emergencia
# T=13501.37 clienteC454: COLA COMERCIAL - llegue con un IA: 52.85
# Atendiendo:[c:60, e:20]
# En cola:[c:17, e:39]
# T=13560.05 clienteC455: COLA COMERCIAL - llegue con un IA: 58.68
# Atendiendo:[c:60, e:20]
# En cola:[c:18, e:39]
# T=13591.42 clienteC456: COLA COMERCIAL - llegue con un IA: 31.37
# Atendiendo:[c:60, e:20]
# En cola:[c:19, e:39]
# T=13633.77 clienteC457: COLA COMERCIAL - llegue con un IA: 42.35
# Atendiendo:[c:60, e:20]
# En cola:[c:20, e:39]
# T=13683.13 clienteC458: COLA COMERCIAL - llegue con un IA: 49.36
# Atendiendo:[c:60, e:20]
# En cola:[c:21, e:39]
# T=13733.83 clienteC459: COLA COMERCIAL - llegue con un IA: 50.70
# Atendiendo:[c:60, e:20]
# En cola:[c:22, e:39]
# T=13751.43, clienteC432: Sali de un puesto comercial
# T=13751.43, clienteE448: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 405.05
# Atendiendo:[c:60, e:20]
# En cola:[c:22, e:39]
# Tiempo de Atencion generado para clienteE448: 178.40
# T=13758.16, clienteC433: Sali de un puesto comercial
# T=13758.16, clienteE451: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 370.43
# Atendiendo:[c:60, e:20]
# En cola:[c:21, e:39]
# Tiempo de Atencion generado para clienteE451: 27.80
# T=13764.35 clienteC460: COLA COMERCIAL - llegue con un IA: 30.52
# Atendiendo:[c:60, e:20]
# En cola:[c:21, e:39]
# T=13785.96, clienteE451: Sali de un puesto de emergencia
# T=13807.41, clienteC435: Sali de un puesto comercial
# T=13807.41, clienteC436: COLA COMERCIAL - Me atendieron despues de esperar 718.47
# Atendiendo:[c:60, e:20]
# En cola:[c:21, e:39]
# Tiempo de Atencion generado para clienteC436: 129.73
# T=13807.86 clienteC461: COLA COMERCIAL - llegue con un IA: 43.51
# Atendiendo:[c:60, e:20]
# En cola:[c:21, e:39]
# T=13861.83 clienteC462: COLA COMERCIAL - llegue con un IA: 53.97
# Atendiendo:[c:60, e:20]
# En cola:[c:22, e:39]
# T=13898.93 clienteC463: COLA COMERCIAL - llegue con un IA: 37.10
# Atendiendo:[c:60, e:20]
# En cola:[c:23, e:39]
# T=13922.55 clienteC464: COLA COMERCIAL - llegue con un IA: 23.62
# Atendiendo:[c:60, e:20]
# En cola:[c:24, e:39]
# T=13929.83, clienteE448: Sali de un puesto de emergencia
# T=13930.54 clienteC465: COLA COMERCIAL - llegue con un IA:  7.99
# Atendiendo:[c:60, e:20]
# En cola:[c:25, e:39]
# T=13937.14, clienteC436: Sali de un puesto comercial
# T=13937.14, clienteC437: COLA COMERCIAL - Me atendieron despues de esperar 813.51
# Atendiendo:[c:60, e:20]
# En cola:[c:25, e:39]
# Tiempo de Atencion generado para clienteC437: 264.71
# T=13937.78 clienteC466: COLA COMERCIAL - llegue con un IA:  7.24
# Atendiendo:[c:60, e:20]
# En cola:[c:25, e:39]
# T=13962.24 clienteE467: COLA EMERGENCIA - llegue con un IA: 24.46
# Atendiendo:[c:60, e:20]
# En cola:[c:26, e:39]
# T=14003.80 clienteC468: COLA COMERCIAL - llegue con un IA: 41.56
# Atendiendo:[c:60, e:20]
# En cola:[c:27, e:40]
# T=14037.04 clienteC469: COLA COMERCIAL - llegue con un IA: 33.23
# Atendiendo:[c:60, e:20]
# En cola:[c:28, e:40]
# T=14071.64 clienteC470: COLA COMERCIAL - llegue con un IA: 34.60
# Atendiendo:[c:60, e:20]
# En cola:[c:29, e:40]
# T=14096.80 clienteC471: COLA COMERCIAL - llegue con un IA: 25.16
# Atendiendo:[c:60, e:20]
# En cola:[c:30, e:40]
# T=14099.53 clienteC472: COLA COMERCIAL - llegue con un IA:  2.73
# Atendiendo:[c:60, e:20]
# En cola:[c:31, e:40]
# T=14153.65 clienteC473: COLA COMERCIAL - llegue con un IA: 54.13
# Atendiendo:[c:60, e:20]
# En cola:[c:32, e:40]
# T=14175.50 clienteC474: COLA COMERCIAL - llegue con un IA: 21.84
# Atendiendo:[c:60, e:20]
# En cola:[c:33, e:40]
# T=14178.80 clienteE475: COLA EMERGENCIA - llegue con un IA:  3.30
# Atendiendo:[c:60, e:20]
# En cola:[c:34, e:40]
# T=14185.43 clienteC476: COLA COMERCIAL - llegue con un IA:  6.64
# Atendiendo:[c:60, e:20]
# En cola:[c:35, e:41]
# T=14201.85, clienteC437: Sali de un puesto comercial
# T=14201.85, clienteE467: COLA EMERGENCIA - Me atendieron en un puesto comercial despues de esperar 239.60
# Atendiendo:[c:60, e:20]
# En cola:[c:35, e:41]
# Tiempo de Atencion generado para clienteE467: 253.83
# T=14202.95 clienteC477: COLA COMERCIAL - llegue con un IA: 17.51
# Atendiendo:[c:60, e:20]
# En cola:[c:35, e:41]
# T=14233.48 clienteC478: COLA COMERCIAL - llegue con un IA: 30.54
# Atendiendo:[c:60, e:20]
# En cola:[c:36, e:41]
# T=14251.96 clienteC479: COLA COMERCIAL - llegue con un IA: 18.47
# Atendiendo:[c:60, e:20]
# En cola:[c:37, e:41]
# T=14262.73 clienteC480: COLA COMERCIAL - llegue con un IA: 10.77
# Atendiendo:[c:60, e:20]
# En cola:[c:38, e:41]
# T=14282.19 clienteC481: COLA COMERCIAL - llegue con un IA: 19.46
# Atendiendo:[c:60, e:20]
# En cola:[c:39, e:41]
# T=14338.63 clienteE482: COLA EMERGENCIA - llegue con un IA: 56.44
# Atendiendo:[c:60, e:20]
# En cola:[c:40, e:41]
# T=14381.99 clienteC483: COLA COMERCIAL - llegue con un IA: 43.35
# Atendiendo:[c:60, e:20]
# En cola:[c:41, e:42]

# %% [markdown]
# Results

# %%
print("===========================================================================")
print("RESULTADOS:")
print("Clientes totales: %1d"%ci["NT"])
PEC = (ci["NEC"] / ci["NT"]) * 100
# Porcentaje de espera menor a 40 segundos
print("Porcentaje de espera en cola menor a 40 segundos: %5.2f"%PEC)
# Objetio: Mayor o igual al 90%

print('Cantidad de puestos comerciales',cantCom)
print('Cantidad de puestos de emergencia',cantEmer)
#print("Cantidad de personales multitasking",ci["multitasking"])
# Out:
# ===========================================================================
# RESULTADOS:
# Clientes totales: 484
# Porcentaje de espera en cola menor a 40 segundos: 85.95
# Cantidad de puestos comerciales 60
# Cantidad de puestos de emergencia 20
