# %% [markdown]
# # TP 12 Simulación - Call Center Metrogas
#
# ## Contexto
# Se dispone de 3 tipos de puestos, y diferentes cantidades de cada uno de ellos:
#
# - Emergencia (E)
# - Comercial (C)
# - Polifuncional (P)
#
# Y dos colas:
#
# - Cola para emergencia (NSE)
# - Cola para comercial (NSC)
#
# Los puestos comerciales y los puestos de emergencia solo atienden su propia cola. Los puestos polifuncionales atienden solo cuando todos los puestos comerciales y/o todos los puestos de emergencia estan ocupados y hay gente esperando en la cola para ser atendido,sera atendido por un polifuncional, dandole mas prioridad a los que estan en la cola de emergencia

# %% [markdown]
# ## Importando librerias de simpy

# %%
#from simpy import initialize
#from SimPy.Simulation import *
import simpy
import random
import collections

# %% [markdown]
# _____

# %% [markdown]
# ## Simulacion de una llegada

# %%
def distribucion_llegada(env,puestos,cont,n):
    while True:
    #for i in range(n):
    
        cont["NT"] += 1
        
        # Genero un cliente random 
        r = random.random()
        #print("Distribucion de generacion de tipo de cliente: %5.2f"%r)
        
        # Si genere un cliente para emergencia
        if r <= cont["PE"]:
            
            ce = Customer(name = "clienteE%02d"%cont["NT"])
            
            # Genero IA para el siguiente cliente y genero el timeout para su llegada 
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA EMERGENCIA - llegue con un IA: %5.2f"%(env.now,ce.name,ia))
            colas(puestos) # Imprimo el estao de las colas
            
            # Genero la llamada
            env.process(ce.llamada_emergencia(env,puestos,cont))
            
        # Si genere un cliente para comercial    
        else: 
            
            cc = Customer(name = "clienteC%02d"%cont["NT"])
            # Genero IA para el siguiente cliente y genero el timeout para su llegada 
            ia = random.uniform(cont["min"],cont["max"])
            yield env.timeout(ia)
            print("T=%5.2f %s: COLA COMERCIAL - llegue con un IA: %5.2f"%(env.now,cc.name,ia))
            colas(puestos) # Imprimo el estao de las colas
            
            # Genero la llamada
            env.process(cc.llamada_comercial(env,puestos,cont))

# %%
class Customer():
    """Evento llegadas/llamadas de los clientes"""
    
    def __init__(self,name):
        self.name = name
        
    def llamada_emergencia(self,env,puestos,cont):
        
        arrive = env.now
        # Pido uso de los dos puestos, y me dan el primero que se libere
        # puestos = [comercial, emergencia, polifuncional]
        emergencia, polifuncional = puestos[1].request(priority=0), puestos[2].request(priority=0)
        atendido = yield emergencia | polifuncional 
        #assert atendido == {emergencia}
        
        # Me atendieron por puestos polifuncionales?
        if polifuncional in atendido:
            cont["multitasking"]+=1
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de polifuncional"%(env.now,self.name))
        
        # Me atendieron por un puesto de emergencia
        else:
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
            
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de emergencia"%(env.now,self.name))
            
            
    def llamada_comercial(self,env,puestos,cont):
        
        arrive = env.now
        # Pido uso de los dos puestos, y me dan el primero que se libere
        # puestos = [comercial, emergencia, polifuncional]
        comercial, polifuncional = puestos[0].request(priority=0), puestos[2].request(priority=1) # comercial tn menos prioridad q emergencia
        atendido = yield comercial | polifuncional 
        
        # Me atendieron por puestos polifuncionales?
        if polifuncional in atendido:
            cont["multitasking"]+=1
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
                
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de polifuncional"%(env.now,self.name))
        
        # Me atendieron por un puesto comercial
        else:
            wait = env.now-arrive #Tiempo de espera
            
            if wait <= 40:
                cont["NEC"] += 1
            
            ta = generar_TA(cont)
            print("T=%5.2f, %s: COLA COMERCIAL - Me atendieron en un puesto comercial despues de esperar %5.2f"%(env.now,self.name,wait))
            colas(puestos)
            print("Tiempo de Atencion generado para %s: %5.2f"%(self.name,ta))
            yield env.timeout(ta)
            print("T=%5.2f, %s: Sali de un puesto de comercial"%(env.now,self.name))

# %%
def colas(p):
    print ("Atendiendo:[c:%1d, e:%1d]"%(p[0].count,p[1].count))
    print ("En cola:[c:%1d, e:%1d]"%(len(p[0].queue),len(p[1].queue)))

# %%
def generar_TA(cont):
    #(a=5,b=615)
    a=5
    b=615
    ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
    
    while ta<a: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta>b:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta>b:
                continue
            else:
                break
        
    while ta>b: 
        ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
        if ta<a:
            ta = abs(random.normalvariate(cont["mu"],cont["sigma"]))
            if ta<a:
                continue
            else:
                break
            
    return ta

# %% [markdown]
# Condiciones Iniciales

# %%
# Experimental data
NT = 0
maxTime = 14400 #segundos
maxClient = 10000
#random.seed(RANDOM_SEED)
PE = 0.12 #Porcentaje Emergencia
PC = 0.88 #Porcentaje Comercial
NEC = 0 #Cantidad de gente que espero en cola menor a 40 segundos
PEC = 0.0 #Porcentaje de espera en cola menor a 40 segundos

# TA - distribucion normal
mu = 267.64 
sigma = 297.40

# IA - uniforme
IAMin = 1
IAMax = 60

# Contadores
ci = {"multitasking":0,
     "mu":mu,
     "sigma":sigma,
     "min":IAMin,
     "max":IAMax,
     "PE":PE,
     "PC":PC,
     "emer":0,
     "com":0,
     "pol":0,
     "NEC":NEC,
     "NT":NT}

# %% [markdown]
# ## Puestos de atencion - variables de control
#
# !! Generar una version para automatizar esto, que genere diferentes combinaciones dado un rango
#
# Y tmbn dejar la opcion de generarlo manualmente

# %%
print('Ingrese cantidad de puestos comerciales')
cantCom = int(input())
ci["com"] = cantCom
print('Ingrese cantidad de puestos de emergencia')
cantEmer = int(input())
ci["emer"] = cantEmer
print('Ingrese cantidad de puestos polifuncionales')
cantPolif = int(input())
ci["pol"] = cantPolif
# Out:
# Ingrese cantidad de puestos comerciales
# 60
# Ingrese cantidad de puestos de emergencia
# 50
# Ingrese cantidad de puestos polifuncionales
# 80

# %% [markdown]
# Modelo de Simulacion

# %%
env = simpy.Environment()
puestos = [simpy.PriorityResource(env,capacity=cantCom),
           simpy.PriorityResource(env,capacity=cantEmer),
           simpy.PriorityResource(env,capacity=cantPolif)] # menor el numero priority, mayor es la prioridad
           
env.process(distribucion_llegada(env,puestos,ci,n=maxClient))
env.run(until=maxTime)
# Out:
# T=49.22 clienteC932: COLA COMERCIAL - llegue con un IA: 49.22
# Atendiendo:[c:0, e:0]
# En cola:[c:0, e:0]
# T=49.22, clienteC932: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC932: 57.16
# T=69.24 clienteC933: COLA COMERCIAL - llegue con un IA: 20.02
# Atendiendo:[c:1, e:0]
# En cola:[c:0, e:0]
# T=69.24, clienteC933: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC933: 88.18
# T=89.44 clienteC934: COLA COMERCIAL - llegue con un IA: 20.21
# Atendiendo:[c:2, e:0]
# En cola:[c:0, e:0]
# T=89.44, clienteC934: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC934: 362.06
# T=106.38, clienteC932: Sali de un puesto de polifuncional
# T=141.80 clienteC935: COLA COMERCIAL - llegue con un IA: 52.35
# Atendiendo:[c:3, e:0]
# En cola:[c:0, e:0]
# T=141.80, clienteC935: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC935: 181.52
# T=157.42, clienteC933: Sali de un puesto de polifuncional
# T=184.38 clienteC936: COLA COMERCIAL - llegue con un IA: 42.58
# Atendiendo:[c:4, e:0]
# En cola:[c:0, e:0]
# T=184.38, clienteC936: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC936: 375.92
# T=210.07 clienteE937: COLA EMERGENCIA - llegue con un IA: 25.69
# Atendiendo:[c:5, e:0]
# En cola:[c:0, e:0]
# T=210.07, clienteE937: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:5, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE937: 75.57
# T=255.45 clienteC938: COLA COMERCIAL - llegue con un IA: 45.38
# Atendiendo:[c:5, e:1]
# En cola:[c:0, e:0]
# T=255.45, clienteC938: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC938: 63.88
# T=267.35 clienteC939: COLA COMERCIAL - llegue con un IA: 11.90
# Atendiendo:[c:6, e:1]
# En cola:[c:0, e:0]
# T=267.35, clienteC939: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC939: 144.15
# T=285.64, clienteE937: Sali de un puesto de polifuncional
# T=319.33, clienteC938: Sali de un puesto de polifuncional
# T=320.66 clienteC940: COLA COMERCIAL - llegue con un IA: 53.31
# Atendiendo:[c:7, e:1]
# En cola:[c:0, e:0]
# T=320.66, clienteC940: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC940: 451.07
# T=323.32, clienteC935: Sali de un puesto de polifuncional
# T=346.17 clienteC941: COLA COMERCIAL - llegue con un IA: 25.51
# Atendiendo:[c:8, e:1]
# En cola:[c:0, e:0]
# T=346.17, clienteC941: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC941: 22.31
# T=368.49, clienteC941: Sali de un puesto de polifuncional
# T=390.21 clienteC942: COLA COMERCIAL - llegue con un IA: 44.03
# Atendiendo:[c:9, e:1]
# En cola:[c:0, e:0]
# T=390.21, clienteC942: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC942: 350.85
# T=411.50, clienteC939: Sali de un puesto de polifuncional
# T=443.17 clienteC943: COLA COMERCIAL - llegue con un IA: 52.96
# Atendiendo:[c:10, e:1]
# En cola:[c:0, e:0]
# T=443.17, clienteC943: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC943: 179.74
# T=451.50, clienteC934: Sali de un puesto de polifuncional
# T=475.47 clienteC944: COLA COMERCIAL - llegue con un IA: 32.30
# Atendiendo:[c:11, e:1]
# En cola:[c:0, e:0]
# T=475.47, clienteC944: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:12, e:1]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC944: 348.06
# T=486.64 clienteE945: COLA EMERGENCIA - llegue con un IA: 11.17
# Atendiendo:[c:12, e:1]
# En cola:[c:0, e:0]
# T=486.64, clienteE945: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE945: 364.59
# T=489.87 clienteC946: COLA COMERCIAL - llegue con un IA:  3.23
# Atendiendo:[c:12, e:2]
# En cola:[c:0, e:0]
# T=489.87, clienteC946: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC946: 292.12
# T=523.43 clienteC947: COLA COMERCIAL - llegue con un IA: 33.56
# Atendiendo:[c:13, e:2]
# En cola:[c:0, e:0]
# T=523.43, clienteC947: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:14, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC947: 143.65
# T=530.84 clienteC948: COLA COMERCIAL - llegue con un IA:  7.41
# Atendiendo:[c:14, e:2]
# En cola:[c:0, e:0]
# T=530.84, clienteC948: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:15, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC948: 76.00
# T=560.30, clienteC936: Sali de un puesto de polifuncional
# T=587.05 clienteC949: COLA COMERCIAL - llegue con un IA: 56.21
# Atendiendo:[c:15, e:2]
# En cola:[c:0, e:0]
# T=587.05, clienteC949: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:16, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC949: 71.79
# T=592.61 clienteC950: COLA COMERCIAL - llegue con un IA:  5.56
# Atendiendo:[c:16, e:2]
# En cola:[c:0, e:0]
# T=592.61, clienteC950: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:17, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC950: 571.31
# T=598.33 clienteC951: COLA COMERCIAL - llegue con un IA:  5.72
# Atendiendo:[c:17, e:2]
# En cola:[c:0, e:0]
# T=598.33, clienteC951: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:18, e:2]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC951: 429.72
# T=606.83, clienteC948: Sali de un puesto de polifuncional
# T=617.35 clienteE952: COLA EMERGENCIA - llegue con un IA: 19.02
# Atendiendo:[c:18, e:2]
# En cola:[c:0, e:0]
# T=617.35, clienteE952: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:18, e:3]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE952: 506.83
# T=622.91, clienteC943: Sali de un puesto de polifuncional
# T=650.74 clienteE953: COLA EMERGENCIA - llegue con un IA: 33.39
# Atendiendo:[c:18, e:3]
# En cola:[c:0, e:0]
# T=650.74, clienteE953: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:18, e:4]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE953: 79.55
# T=655.40 clienteE954: COLA EMERGENCIA - llegue con un IA:  4.66
# Atendiendo:[c:18, e:4]
# En cola:[c:0, e:0]
# T=655.40, clienteE954: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:18, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE954: 509.63
# T=658.84, clienteC949: Sali de un puesto de polifuncional
# T=667.08, clienteC947: Sali de un puesto de polifuncional
# T=707.26 clienteC955: COLA COMERCIAL - llegue con un IA: 51.86
# Atendiendo:[c:18, e:5]
# En cola:[c:0, e:0]
# T=707.26, clienteC955: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:19, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC955: 114.05
# T=730.29, clienteE953: Sali de un puesto de polifuncional
# T=741.05, clienteC942: Sali de un puesto de polifuncional
# T=759.99 clienteC956: COLA COMERCIAL - llegue con un IA: 52.73
# Atendiendo:[c:19, e:5]
# En cola:[c:0, e:0]
# T=759.99, clienteC956: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:20, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC956: 27.12
# T=771.73, clienteC940: Sali de un puesto de polifuncional
# T=781.99, clienteC946: Sali de un puesto de polifuncional
# T=787.11, clienteC956: Sali de un puesto de polifuncional
# T=808.99 clienteC957: COLA COMERCIAL - llegue con un IA: 49.00
# Atendiendo:[c:20, e:5]
# En cola:[c:0, e:0]
# T=808.99, clienteC957: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:21, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC957: 78.39
# T=821.30, clienteC955: Sali de un puesto de polifuncional
# T=823.53, clienteC944: Sali de un puesto de polifuncional
# T=830.63 clienteC958: COLA COMERCIAL - llegue con un IA: 21.65
# Atendiendo:[c:21, e:5]
# En cola:[c:0, e:0]
# T=830.63, clienteC958: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:22, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC958: 201.32
# T=832.09 clienteC959: COLA COMERCIAL - llegue con un IA:  1.46
# Atendiendo:[c:22, e:5]
# En cola:[c:0, e:0]
# T=832.09, clienteC959: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:23, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC959: 519.34
# T=851.23, clienteE945: Sali de un puesto de polifuncional
# T=853.91 clienteC960: COLA COMERCIAL - llegue con un IA: 21.82
# Atendiendo:[c:23, e:5]
# En cola:[c:0, e:0]
# T=853.91, clienteC960: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:24, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC960: 321.92
# T=881.31 clienteC961: COLA COMERCIAL - llegue con un IA: 27.39
# Atendiendo:[c:24, e:5]
# En cola:[c:0, e:0]
# T=881.31, clienteC961: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:25, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC961: 62.03
# T=887.38, clienteC957: Sali de un puesto de polifuncional
# T=938.21 clienteC962: COLA COMERCIAL - llegue con un IA: 56.90
# Atendiendo:[c:25, e:5]
# En cola:[c:0, e:0]
# T=938.21, clienteC962: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:26, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC962: 320.35
# T=943.33, clienteC961: Sali de un puesto de polifuncional
# T=951.82 clienteC963: COLA COMERCIAL - llegue con un IA: 13.61
# Atendiendo:[c:26, e:5]
# En cola:[c:0, e:0]
# T=951.82, clienteC963: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:27, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC963: 456.01
# T=967.25 clienteC964: COLA COMERCIAL - llegue con un IA: 15.43
# Atendiendo:[c:27, e:5]
# En cola:[c:0, e:0]
# T=967.25, clienteC964: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:28, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC964: 368.17
# T=1003.82 clienteC965: COLA COMERCIAL - llegue con un IA: 36.56
# Atendiendo:[c:28, e:5]
# En cola:[c:0, e:0]
# T=1003.82, clienteC965: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:29, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC965: 245.28
# T=1028.05, clienteC951: Sali de un puesto de polifuncional
# T=1031.95, clienteC958: Sali de un puesto de polifuncional
# T=1062.08 clienteC966: COLA COMERCIAL - llegue con un IA: 58.27
# Atendiendo:[c:29, e:5]
# En cola:[c:0, e:0]
# T=1062.08, clienteC966: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:30, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC966: 352.82
# T=1107.14 clienteC967: COLA COMERCIAL - llegue con un IA: 45.05
# Atendiendo:[c:30, e:5]
# En cola:[c:0, e:0]
# T=1107.14, clienteC967: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:31, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC967: 300.52
# T=1108.45 clienteC968: COLA COMERCIAL - llegue con un IA:  1.31
# Atendiendo:[c:31, e:5]
# En cola:[c:0, e:0]
# T=1108.45, clienteC968: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:32, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC968: 448.22
# T=1124.15 clienteC969: COLA COMERCIAL - llegue con un IA: 15.70
# Atendiendo:[c:32, e:5]
# En cola:[c:0, e:0]
# T=1124.15, clienteC969: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:33, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC969: 145.80
# T=1124.18, clienteE952: Sali de un puesto de polifuncional
# T=1163.92, clienteC950: Sali de un puesto de polifuncional
# T=1165.03, clienteE954: Sali de un puesto de polifuncional
# T=1169.31 clienteC970: COLA COMERCIAL - llegue con un IA: 45.17
# Atendiendo:[c:33, e:5]
# En cola:[c:0, e:0]
# T=1169.31, clienteC970: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:34, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC970: 480.92
# T=1175.83, clienteC960: Sali de un puesto de polifuncional
# T=1198.36 clienteC971: COLA COMERCIAL - llegue con un IA: 29.05
# Atendiendo:[c:34, e:5]
# En cola:[c:0, e:0]
# T=1198.36, clienteC971: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:35, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC971: 33.76
# T=1219.22 clienteC972: COLA COMERCIAL - llegue con un IA: 20.85
# Atendiendo:[c:35, e:5]
# En cola:[c:0, e:0]
# T=1219.22, clienteC972: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:36, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC972: 463.76
# T=1232.12, clienteC971: Sali de un puesto de polifuncional
# T=1249.10, clienteC965: Sali de un puesto de polifuncional
# T=1258.56, clienteC962: Sali de un puesto de polifuncional
# T=1269.95, clienteC969: Sali de un puesto de polifuncional
# T=1276.57 clienteC973: COLA COMERCIAL - llegue con un IA: 57.36
# Atendiendo:[c:36, e:5]
# En cola:[c:0, e:0]
# T=1276.57, clienteC973: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:37, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC973: 514.99
# T=1309.89 clienteC974: COLA COMERCIAL - llegue con un IA: 33.32
# Atendiendo:[c:37, e:5]
# En cola:[c:0, e:0]
# T=1309.89, clienteC974: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:38, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC974: 420.53
# T=1333.93 clienteC975: COLA COMERCIAL - llegue con un IA: 24.04
# Atendiendo:[c:38, e:5]
# En cola:[c:0, e:0]
# T=1333.93, clienteC975: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:39, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC975: 298.72
# T=1335.43, clienteC964: Sali de un puesto de polifuncional
# T=1351.43, clienteC959: Sali de un puesto de polifuncional
# T=1367.28 clienteC976: COLA COMERCIAL - llegue con un IA: 33.35
# Atendiendo:[c:39, e:5]
# En cola:[c:0, e:0]
# T=1367.28, clienteC976: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:40, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC976: 168.59
# T=1377.13 clienteC977: COLA COMERCIAL - llegue con un IA:  9.85
# Atendiendo:[c:40, e:5]
# En cola:[c:0, e:0]
# T=1377.13, clienteC977: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:41, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC977: 434.12
# T=1385.18 clienteC978: COLA COMERCIAL - llegue con un IA:  8.05
# Atendiendo:[c:41, e:5]
# En cola:[c:0, e:0]
# T=1385.18, clienteC978: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:42, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC978: 111.80
# T=1394.72 clienteC979: COLA COMERCIAL - llegue con un IA:  9.54
# Atendiendo:[c:42, e:5]
# En cola:[c:0, e:0]
# T=1394.72, clienteC979: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:43, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC979: 209.86
# T=1407.66, clienteC967: Sali de un puesto de polifuncional
# T=1407.83, clienteC963: Sali de un puesto de polifuncional
# T=1414.90, clienteC966: Sali de un puesto de polifuncional
# T=1428.93 clienteC980: COLA COMERCIAL - llegue con un IA: 34.21
# Atendiendo:[c:43, e:5]
# En cola:[c:0, e:0]
# T=1428.93, clienteC980: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:44, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC980: 479.24
# T=1430.28 clienteC981: COLA COMERCIAL - llegue con un IA:  1.35
# Atendiendo:[c:44, e:5]
# En cola:[c:0, e:0]
# T=1430.28, clienteC981: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:45, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC981: 291.48
# T=1482.25 clienteC982: COLA COMERCIAL - llegue con un IA: 51.97
# Atendiendo:[c:45, e:5]
# En cola:[c:0, e:0]
# T=1482.25, clienteC982: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:46, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC982: 274.88
# T=1496.98, clienteC978: Sali de un puesto de polifuncional
# T=1507.40 clienteC983: COLA COMERCIAL - llegue con un IA: 25.15
# Atendiendo:[c:46, e:5]
# En cola:[c:0, e:0]
# T=1507.40, clienteC983: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:47, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC983: 497.20
# T=1535.87, clienteC976: Sali de un puesto de polifuncional
# T=1554.55 clienteC984: COLA COMERCIAL - llegue con un IA: 47.15
# Atendiendo:[c:47, e:5]
# En cola:[c:0, e:0]
# T=1554.55, clienteC984: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:48, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC984: 181.43
# T=1556.66, clienteC968: Sali de un puesto de polifuncional
# T=1602.26 clienteC985: COLA COMERCIAL - llegue con un IA: 47.71
# Atendiendo:[c:48, e:5]
# En cola:[c:0, e:0]
# T=1602.26, clienteC985: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:49, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC985: 138.21
# T=1604.57, clienteC979: Sali de un puesto de polifuncional
# T=1632.65, clienteC975: Sali de un puesto de polifuncional
# T=1646.40 clienteC986: COLA COMERCIAL - llegue con un IA: 44.15
# Atendiendo:[c:49, e:5]
# En cola:[c:0, e:0]
# T=1646.40, clienteC986: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:50, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC986: 481.08
# T=1650.23, clienteC970: Sali de un puesto de polifuncional
# T=1682.98, clienteC972: Sali de un puesto de polifuncional
# T=1688.03 clienteC987: COLA COMERCIAL - llegue con un IA: 41.63
# Atendiendo:[c:50, e:5]
# En cola:[c:0, e:0]
# T=1688.03, clienteC987: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:51, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC987: 93.47
# T=1721.76, clienteC981: Sali de un puesto de polifuncional
# T=1730.42, clienteC974: Sali de un puesto de polifuncional
# T=1735.98, clienteC984: Sali de un puesto de polifuncional
# T=1740.47, clienteC985: Sali de un puesto de polifuncional
# T=1741.54 clienteC988: COLA COMERCIAL - llegue con un IA: 53.51
# Atendiendo:[c:51, e:5]
# En cola:[c:0, e:0]
# T=1741.54, clienteC988: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:52, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC988: 64.32
# T=1757.14, clienteC982: Sali de un puesto de polifuncional
# T=1781.50, clienteC987: Sali de un puesto de polifuncional
# T=1786.34 clienteC989: COLA COMERCIAL - llegue con un IA: 44.80
# Atendiendo:[c:52, e:5]
# En cola:[c:0, e:0]
# T=1786.34, clienteC989: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:53, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC989: 124.86
# T=1791.56, clienteC973: Sali de un puesto de polifuncional
# T=1805.86, clienteC988: Sali de un puesto de polifuncional
# T=1811.25, clienteC977: Sali de un puesto de polifuncional
# T=1844.59 clienteC990: COLA COMERCIAL - llegue con un IA: 58.25
# Atendiendo:[c:53, e:5]
# En cola:[c:0, e:0]
# T=1844.59, clienteC990: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:54, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC990: 101.62
# T=1871.34 clienteC991: COLA COMERCIAL - llegue con un IA: 26.75
# Atendiendo:[c:54, e:5]
# En cola:[c:0, e:0]
# T=1871.34, clienteC991: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:55, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC991: 299.19
# T=1906.79 clienteC992: COLA COMERCIAL - llegue con un IA: 35.45
# Atendiendo:[c:55, e:5]
# En cola:[c:0, e:0]
# T=1906.79, clienteC992: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:56, e:5]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC992: 491.61
# T=1908.17, clienteC980: Sali de un puesto de polifuncional
# T=1911.19, clienteC989: Sali de un puesto de polifuncional
# T=1929.38 clienteE993: COLA EMERGENCIA - llegue con un IA: 22.59
# Atendiendo:[c:56, e:5]
# En cola:[c:0, e:0]
# T=1929.38, clienteE993: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:56, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteE993: 204.75
# T=1946.21, clienteC990: Sali de un puesto de polifuncional
# T=1956.82 clienteC994: COLA COMERCIAL - llegue con un IA: 27.44
# Atendiendo:[c:56, e:6]
# En cola:[c:0, e:0]
# T=1956.82, clienteC994: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:57, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC994: 141.65
# T=1964.45 clienteC995: COLA COMERCIAL - llegue con un IA:  7.63
# Atendiendo:[c:57, e:6]
# En cola:[c:0, e:0]
# T=1964.45, clienteC995: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:58, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC995: 269.44
# T=1998.14 clienteC996: COLA COMERCIAL - llegue con un IA: 33.70
# Atendiendo:[c:58, e:6]
# En cola:[c:0, e:0]
# T=1998.14, clienteC996: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:59, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC996: 232.57
# T=2004.59, clienteC983: Sali de un puesto de polifuncional
# T=2032.51 clienteC997: COLA COMERCIAL - llegue con un IA: 34.37
# Atendiendo:[c:59, e:6]
# En cola:[c:0, e:0]
# T=2032.51, clienteC997: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:6]
# En cola:[c:0, e:0]
# Tiempo de Atencion generado para clienteC997: 457.35
# T=2059.99 clienteC998: COLA COMERCIAL - llegue con un IA: 27.48
# Atendiendo:[c:60, e:6]
# En cola:[c:0, e:0]
# T=2059.99, clienteC998: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:6]
# En cola:[c:1, e:0]
# Tiempo de Atencion generado para clienteC998: 263.44
# T=2098.47, clienteC994: Sali de un puesto de polifuncional
# T=2114.10 clienteE999: COLA EMERGENCIA - llegue con un IA: 54.11
# Atendiendo:[c:60, e:6]
# En cola:[c:1, e:0]
# T=2114.10, clienteE999: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:7]
# En cola:[c:1, e:0]
# Tiempo de Atencion generado para clienteE999: 340.76
# T=2125.90 clienteC1000: COLA COMERCIAL - llegue con un IA: 11.80
# Atendiendo:[c:60, e:7]
# En cola:[c:1, e:0]
# T=2125.90, clienteC1000: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:7]
# En cola:[c:2, e:0]
# Tiempo de Atencion generado para clienteC1000: 253.20
# T=2127.48, clienteC986: Sali de un puesto de polifuncional
# T=2129.84 clienteE1001: COLA EMERGENCIA - llegue con un IA:  3.94
# Atendiendo:[c:60, e:7]
# En cola:[c:2, e:0]
# T=2129.84, clienteE1001: COLA EMERGENCIA - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:2, e:0]
# Tiempo de Atencion generado para clienteE1001: 101.22
# T=2134.14, clienteE993: Sali de un puesto de polifuncional
# T=2144.65 clienteC1002: COLA COMERCIAL - llegue con un IA: 14.81
# Atendiendo:[c:60, e:8]
# En cola:[c:2, e:0]
# T=2144.65, clienteC1002: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:3, e:0]
# Tiempo de Atencion generado para clienteC1002: 111.81
# T=2170.54, clienteC991: Sali de un puesto de polifuncional
# T=2178.39 clienteC1003: COLA COMERCIAL - llegue con un IA: 33.73
# Atendiendo:[c:60, e:8]
# En cola:[c:3, e:0]
# T=2178.39, clienteC1003: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:4, e:0]
# Tiempo de Atencion generado para clienteC1003: 155.55
# T=2230.72, clienteC996: Sali de un puesto de polifuncional
# T=2231.06, clienteE1001: Sali de un puesto de polifuncional
# T=2232.79 clienteC1004: COLA COMERCIAL - llegue con un IA: 54.40
# Atendiendo:[c:60, e:8]
# En cola:[c:4, e:0]
# T=2232.79, clienteC1004: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:5, e:0]
# Tiempo de Atencion generado para clienteC1004: 529.01
# T=2233.89, clienteC995: Sali de un puesto de polifuncional
# T=2256.46, clienteC1002: Sali de un puesto de polifuncional
# T=2283.03 clienteC1005: COLA COMERCIAL - llegue con un IA: 50.25
# Atendiendo:[c:60, e:8]
# En cola:[c:5, e:0]
# T=2283.03, clienteC1005: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:6, e:0]
# Tiempo de Atencion generado para clienteC1005: 418.21
# T=2313.34 clienteC1006: COLA COMERCIAL - llegue con un IA: 30.30
# Atendiendo:[c:60, e:8]
# En cola:[c:6, e:0]
# T=2313.34, clienteC1006: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:7, e:0]
# Tiempo de Atencion generado para clienteC1006: 220.29
# T=2323.43, clienteC998: Sali de un puesto de polifuncional
# T=2333.94, clienteC1003: Sali de un puesto de polifuncional
# T=2335.47 clienteC1007: COLA COMERCIAL - llegue con un IA: 22.13
# Atendiendo:[c:60, e:8]
# En cola:[c:7, e:0]
# T=2335.47, clienteC1007: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:8, e:0]
# Tiempo de Atencion generado para clienteC1007: 426.82
# T=2371.20 clienteC1008: COLA COMERCIAL - llegue con un IA: 35.74
# Atendiendo:[c:60, e:8]
# En cola:[c:8, e:0]
# T=2371.20, clienteC1008: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:9, e:0]
# Tiempo de Atencion generado para clienteC1008: 225.74
# T=2379.10, clienteC1000: Sali de un puesto de polifuncional
# T=2398.40, clienteC992: Sali de un puesto de polifuncional
# T=2401.61 clienteC1009: COLA COMERCIAL - llegue con un IA: 30.40
# Atendiendo:[c:60, e:8]
# En cola:[c:9, e:0]
# T=2401.61, clienteC1009: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:10, e:0]
# Tiempo de Atencion generado para clienteC1009: 321.39
# T=2450.05 clienteC1010: COLA COMERCIAL - llegue con un IA: 48.44
# Atendiendo:[c:60, e:8]
# En cola:[c:10, e:0]
# T=2450.05, clienteC1010: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:11, e:0]
# Tiempo de Atencion generado para clienteC1010: 325.55
# T=2454.86, clienteE999: Sali de un puesto de polifuncional
# T=2486.85 clienteC1011: COLA COMERCIAL - llegue con un IA: 36.80
# Atendiendo:[c:60, e:8]
# En cola:[c:11, e:0]
# T=2486.85, clienteC1011: COLA COMERCIAL - Me atendieron en un puesto polifuncional despues de esperar  0.00
# Atendiendo:[c:60, e:8]
# En cola:[c:12, e:0]
# Tiempo de Atencion generado para clienteC1011: 557.52
# T=2489.86, clienteC997: Sali de un puesto de polifuncional
# T=2507.58 clienteC1012: COLA COMERCIAL - llegue con un IA: 20.73
# Atendiendo:[c:60, e:8]
# En cola:[c:12, e:0]
# T=2533.63, clienteC1006: Sali de un puesto de polifuncional
# T=2551.54 clienteE1013: COLA EMERGENCIA - llegue con un IA: 43.96
# Atendiendo:[c:60, e:8]
# En cola:[c:13, e:0]
# T=2551.54, clienteE1013: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:9]
# En cola:[c:13, e:0]
# Tiempo de Atencion generado para clienteE1013: 405.47
# T=2573.21 clienteC1014: COLA COMERCIAL - llegue con un IA: 21.67
# Atendiendo:[c:60, e:9]
# En cola:[c:13, e:0]
# T=2596.95, clienteC1008: Sali de un puesto de polifuncional
# T=2603.16 clienteC1015: COLA COMERCIAL - llegue con un IA: 29.95
# Atendiendo:[c:60, e:9]
# En cola:[c:14, e:0]
# T=2641.97 clienteE1016: COLA EMERGENCIA - llegue con un IA: 38.81
# Atendiendo:[c:60, e:9]
# En cola:[c:15, e:0]
# T=2641.97, clienteE1016: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:10]
# En cola:[c:15, e:0]
# Tiempo de Atencion generado para clienteE1016: 421.89
# T=2695.24 clienteC1017: COLA COMERCIAL - llegue con un IA: 53.26
# Atendiendo:[c:60, e:10]
# En cola:[c:15, e:0]
# T=2701.24, clienteC1005: Sali de un puesto de polifuncional
# T=2723.00, clienteC1009: Sali de un puesto de polifuncional
# T=2738.81 clienteC1018: COLA COMERCIAL - llegue con un IA: 43.57
# Atendiendo:[c:60, e:10]
# En cola:[c:16, e:0]
# T=2761.79, clienteC1004: Sali de un puesto de polifuncional
# T=2762.29, clienteC1007: Sali de un puesto de polifuncional
# T=2765.05 clienteC1019: COLA COMERCIAL - llegue con un IA: 26.25
# Atendiendo:[c:60, e:10]
# En cola:[c:17, e:0]
# T=2775.59, clienteC1010: Sali de un puesto de polifuncional
# T=2789.60 clienteC1020: COLA COMERCIAL - llegue con un IA: 24.55
# Atendiendo:[c:60, e:10]
# En cola:[c:18, e:0]
# T=2830.49 clienteC1021: COLA COMERCIAL - llegue con un IA: 40.89
# Atendiendo:[c:60, e:10]
# En cola:[c:19, e:0]
# T=2877.85 clienteE1022: COLA EMERGENCIA - llegue con un IA: 47.36
# Atendiendo:[c:60, e:10]
# En cola:[c:20, e:0]
# T=2877.85, clienteE1022: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:11]
# En cola:[c:20, e:0]
# Tiempo de Atencion generado para clienteE1022: 315.51
# T=2893.65 clienteC1023: COLA COMERCIAL - llegue con un IA: 15.80
# Atendiendo:[c:60, e:11]
# En cola:[c:20, e:0]
# T=2924.37 clienteC1024: COLA COMERCIAL - llegue con un IA: 30.72
# Atendiendo:[c:60, e:11]
# En cola:[c:21, e:0]
# T=2957.01, clienteE1013: Sali de un puesto de emergencia
# T=2967.75 clienteC1025: COLA COMERCIAL - llegue con un IA: 43.38
# Atendiendo:[c:60, e:11]
# En cola:[c:22, e:0]
# T=3019.48 clienteC1026: COLA COMERCIAL - llegue con un IA: 51.73
# Atendiendo:[c:60, e:11]
# En cola:[c:23, e:0]
# T=3044.37, clienteC1011: Sali de un puesto de polifuncional
# T=3048.31 clienteC1027: COLA COMERCIAL - llegue con un IA: 28.83
# Atendiendo:[c:60, e:11]
# En cola:[c:24, e:0]
# T=3063.86, clienteE1016: Sali de un puesto de emergencia
# T=3083.94 clienteC1028: COLA COMERCIAL - llegue con un IA: 35.63
# Atendiendo:[c:60, e:11]
# En cola:[c:25, e:0]
# T=3139.01 clienteC1029: COLA COMERCIAL - llegue con un IA: 55.07
# Atendiendo:[c:60, e:11]
# En cola:[c:26, e:0]
# T=3161.36 clienteC1030: COLA COMERCIAL - llegue con un IA: 22.35
# Atendiendo:[c:60, e:11]
# En cola:[c:27, e:0]
# T=3193.35, clienteE1022: Sali de un puesto de emergencia
# T=3218.70 clienteC1031: COLA COMERCIAL - llegue con un IA: 57.33
# Atendiendo:[c:60, e:11]
# En cola:[c:28, e:0]
# T=3254.88 clienteC1032: COLA COMERCIAL - llegue con un IA: 36.18
# Atendiendo:[c:60, e:11]
# En cola:[c:29, e:0]
# T=3302.88 clienteE1033: COLA EMERGENCIA - llegue con un IA: 48.00
# Atendiendo:[c:60, e:11]
# En cola:[c:30, e:0]
# T=3302.88, clienteE1033: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:12]
# En cola:[c:30, e:0]
# Tiempo de Atencion generado para clienteE1033: 229.40
# T=3308.06 clienteC1034: COLA COMERCIAL - llegue con un IA:  5.18
# Atendiendo:[c:60, e:12]
# En cola:[c:30, e:0]
# T=3323.20 clienteC1035: COLA COMERCIAL - llegue con un IA: 15.14
# Atendiendo:[c:60, e:12]
# En cola:[c:31, e:0]
# T=3324.25 clienteE1036: COLA EMERGENCIA - llegue con un IA:  1.05
# Atendiendo:[c:60, e:12]
# En cola:[c:32, e:0]
# T=3324.25, clienteE1036: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:13]
# En cola:[c:32, e:0]
# Tiempo de Atencion generado para clienteE1036: 93.11
# T=3351.46 clienteC1037: COLA COMERCIAL - llegue con un IA: 27.21
# Atendiendo:[c:60, e:13]
# En cola:[c:32, e:0]
# T=3399.23 clienteC1038: COLA COMERCIAL - llegue con un IA: 47.77
# Atendiendo:[c:60, e:13]
# En cola:[c:33, e:0]
# T=3417.36, clienteE1036: Sali de un puesto de emergencia
# T=3442.90 clienteE1039: COLA EMERGENCIA - llegue con un IA: 43.66
# Atendiendo:[c:60, e:13]
# En cola:[c:34, e:0]
# T=3442.90, clienteE1039: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:14]
# En cola:[c:34, e:0]
# Tiempo de Atencion generado para clienteE1039: 248.93
# T=3484.63 clienteC1040: COLA COMERCIAL - llegue con un IA: 41.73
# Atendiendo:[c:60, e:14]
# En cola:[c:34, e:0]
# T=3486.42 clienteC1041: COLA COMERCIAL - llegue con un IA:  1.79
# Atendiendo:[c:60, e:14]
# En cola:[c:35, e:0]
# T=3532.28, clienteE1033: Sali de un puesto de emergencia
# T=3538.83 clienteC1042: COLA COMERCIAL - llegue con un IA: 52.41
# Atendiendo:[c:60, e:14]
# En cola:[c:36, e:0]
# T=3598.02 clienteC1043: COLA COMERCIAL - llegue con un IA: 59.19
# Atendiendo:[c:60, e:14]
# En cola:[c:37, e:0]
# T=3637.76 clienteC1044: COLA COMERCIAL - llegue con un IA: 39.74
# Atendiendo:[c:60, e:14]
# En cola:[c:38, e:0]
# T=3668.97 clienteC1045: COLA COMERCIAL - llegue con un IA: 31.21
# Atendiendo:[c:60, e:14]
# En cola:[c:39, e:0]
# T=3691.83, clienteE1039: Sali de un puesto de emergencia
# T=3716.74 clienteC1046: COLA COMERCIAL - llegue con un IA: 47.76
# Atendiendo:[c:60, e:14]
# En cola:[c:40, e:0]
# T=3733.73 clienteC1047: COLA COMERCIAL - llegue con un IA: 16.99
# Atendiendo:[c:60, e:14]
# En cola:[c:41, e:0]
# T=3760.11 clienteC1048: COLA COMERCIAL - llegue con un IA: 26.38
# Atendiendo:[c:60, e:14]
# En cola:[c:42, e:0]
# T=3807.47 clienteC1049: COLA COMERCIAL - llegue con un IA: 47.36
# Atendiendo:[c:60, e:14]
# En cola:[c:43, e:0]
# T=3861.90 clienteC1050: COLA COMERCIAL - llegue con un IA: 54.43
# Atendiendo:[c:60, e:14]
# En cola:[c:44, e:0]
# T=3890.04 clienteC1051: COLA COMERCIAL - llegue con un IA: 28.14
# Atendiendo:[c:60, e:14]
# En cola:[c:45, e:0]
# T=3947.29 clienteC1052: COLA COMERCIAL - llegue con un IA: 57.25
# Atendiendo:[c:60, e:14]
# En cola:[c:46, e:0]
# T=3952.36 clienteE1053: COLA EMERGENCIA - llegue con un IA:  5.07
# Atendiendo:[c:60, e:14]
# En cola:[c:47, e:0]
# T=3952.36, clienteE1053: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:15]
# En cola:[c:47, e:0]
# Tiempo de Atencion generado para clienteE1053: 415.81
# T=3982.00 clienteC1054: COLA COMERCIAL - llegue con un IA: 29.64
# Atendiendo:[c:60, e:15]
# En cola:[c:47, e:0]
# T=4013.47 clienteC1055: COLA COMERCIAL - llegue con un IA: 31.47
# Atendiendo:[c:60, e:15]
# En cola:[c:48, e:0]
# T=4054.10 clienteC1056: COLA COMERCIAL - llegue con un IA: 40.63
# Atendiendo:[c:60, e:15]
# En cola:[c:49, e:0]
# T=4091.78 clienteC1057: COLA COMERCIAL - llegue con un IA: 37.68
# Atendiendo:[c:60, e:15]
# En cola:[c:50, e:0]
# T=4149.00 clienteC1058: COLA COMERCIAL - llegue con un IA: 57.22
# Atendiendo:[c:60, e:15]
# En cola:[c:51, e:0]
# T=4157.33 clienteE1059: COLA EMERGENCIA - llegue con un IA:  8.33
# Atendiendo:[c:60, e:15]
# En cola:[c:52, e:0]
# T=4157.33, clienteE1059: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:16]
# En cola:[c:52, e:0]
# Tiempo de Atencion generado para clienteE1059: 246.11
# T=4180.22 clienteC1060: COLA COMERCIAL - llegue con un IA: 22.88
# Atendiendo:[c:60, e:16]
# En cola:[c:52, e:0]
# T=4237.88 clienteC1061: COLA COMERCIAL - llegue con un IA: 57.66
# Atendiendo:[c:60, e:16]
# En cola:[c:53, e:0]
# T=4287.21 clienteC1062: COLA COMERCIAL - llegue con un IA: 49.33
# Atendiendo:[c:60, e:16]
# En cola:[c:54, e:0]
# T=4346.26 clienteC1063: COLA COMERCIAL - llegue con un IA: 59.05
# Atendiendo:[c:60, e:16]
# En cola:[c:55, e:0]
# T=4368.17, clienteE1053: Sali de un puesto de emergencia
# T=4383.19 clienteC1064: COLA COMERCIAL - llegue con un IA: 36.93
# Atendiendo:[c:60, e:16]
# En cola:[c:56, e:0]
# T=4403.44, clienteE1059: Sali de un puesto de emergencia
# T=4409.33 clienteC1065: COLA COMERCIAL - llegue con un IA: 26.14
# Atendiendo:[c:60, e:16]
# En cola:[c:57, e:0]
# T=4455.14 clienteC1066: COLA COMERCIAL - llegue con un IA: 45.81
# Atendiendo:[c:60, e:16]
# En cola:[c:58, e:0]
# T=4491.52 clienteC1067: COLA COMERCIAL - llegue con un IA: 36.37
# Atendiendo:[c:60, e:16]
# En cola:[c:59, e:0]
# T=4504.48 clienteC1068: COLA COMERCIAL - llegue con un IA: 12.96
# Atendiendo:[c:60, e:16]
# En cola:[c:60, e:0]
# T=4514.19 clienteC1069: COLA COMERCIAL - llegue con un IA:  9.72
# Atendiendo:[c:60, e:16]
# En cola:[c:61, e:0]
# T=4557.56 clienteC1070: COLA COMERCIAL - llegue con un IA: 43.37
# Atendiendo:[c:60, e:16]
# En cola:[c:62, e:0]
# T=4559.49 clienteC1071: COLA COMERCIAL - llegue con un IA:  1.93
# Atendiendo:[c:60, e:16]
# En cola:[c:63, e:0]
# T=4617.03 clienteC1072: COLA COMERCIAL - llegue con un IA: 57.54
# Atendiendo:[c:60, e:16]
# En cola:[c:64, e:0]
# T=4641.54 clienteE1073: COLA EMERGENCIA - llegue con un IA: 24.51
# Atendiendo:[c:60, e:16]
# En cola:[c:65, e:0]
# T=4641.54, clienteE1073: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:17]
# En cola:[c:65, e:0]
# Tiempo de Atencion generado para clienteE1073: 367.35
# T=4690.64 clienteC1074: COLA COMERCIAL - llegue con un IA: 49.09
# Atendiendo:[c:60, e:17]
# En cola:[c:65, e:0]
# T=4749.03 clienteC1075: COLA COMERCIAL - llegue con un IA: 58.39
# Atendiendo:[c:60, e:17]
# En cola:[c:66, e:0]
# T=4790.34 clienteC1076: COLA COMERCIAL - llegue con un IA: 41.31
# Atendiendo:[c:60, e:17]
# En cola:[c:67, e:0]
# T=4820.62 clienteE1077: COLA EMERGENCIA - llegue con un IA: 30.28
# Atendiendo:[c:60, e:17]
# En cola:[c:68, e:0]
# T=4820.62, clienteE1077: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:18]
# En cola:[c:68, e:0]
# Tiempo de Atencion generado para clienteE1077: 101.43
# T=4867.99 clienteE1078: COLA EMERGENCIA - llegue con un IA: 47.37
# Atendiendo:[c:60, e:18]
# En cola:[c:68, e:0]
# T=4867.99, clienteE1078: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:19]
# En cola:[c:68, e:0]
# Tiempo de Atencion generado para clienteE1078: 103.23
# T=4893.33 clienteC1079: COLA COMERCIAL - llegue con un IA: 25.34
# Atendiendo:[c:60, e:19]
# En cola:[c:68, e:0]
# T=4910.98 clienteE1080: COLA EMERGENCIA - llegue con un IA: 17.66
# Atendiendo:[c:60, e:19]
# En cola:[c:69, e:0]
# T=4910.98, clienteE1080: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:20]
# En cola:[c:69, e:0]
# Tiempo de Atencion generado para clienteE1080: 208.50
# T=4922.06, clienteE1077: Sali de un puesto de emergencia
# T=4943.61 clienteC1081: COLA COMERCIAL - llegue con un IA: 32.63
# Atendiendo:[c:60, e:20]
# En cola:[c:69, e:0]
# T=4964.66 clienteC1082: COLA COMERCIAL - llegue con un IA: 21.05
# Atendiendo:[c:60, e:20]
# En cola:[c:70, e:0]
# T=4971.22, clienteE1078: Sali de un puesto de emergencia
# T=4990.84 clienteC1083: COLA COMERCIAL - llegue con un IA: 26.19
# Atendiendo:[c:60, e:20]
# En cola:[c:71, e:0]
# T=5008.89, clienteE1073: Sali de un puesto de emergencia
# T=5047.36 clienteC1084: COLA COMERCIAL - llegue con un IA: 56.51
# Atendiendo:[c:60, e:20]
# En cola:[c:72, e:0]
# T=5082.28 clienteC1085: COLA COMERCIAL - llegue con un IA: 34.92
# Atendiendo:[c:60, e:20]
# En cola:[c:73, e:0]
# T=5119.49, clienteE1080: Sali de un puesto de emergencia
# T=5126.36 clienteC1086: COLA COMERCIAL - llegue con un IA: 44.08
# Atendiendo:[c:60, e:20]
# En cola:[c:74, e:0]
# T=5145.04 clienteC1087: COLA COMERCIAL - llegue con un IA: 18.68
# Atendiendo:[c:60, e:20]
# En cola:[c:75, e:0]
# T=5149.65 clienteC1088: COLA COMERCIAL - llegue con un IA:  4.60
# Atendiendo:[c:60, e:20]
# En cola:[c:76, e:0]
# T=5192.60 clienteC1089: COLA COMERCIAL - llegue con un IA: 42.95
# Atendiendo:[c:60, e:20]
# En cola:[c:77, e:0]
# T=5235.81 clienteC1090: COLA COMERCIAL - llegue con un IA: 43.22
# Atendiendo:[c:60, e:20]
# En cola:[c:78, e:0]
# T=5245.26 clienteC1091: COLA COMERCIAL - llegue con un IA:  9.45
# Atendiendo:[c:60, e:20]
# En cola:[c:79, e:0]
# T=5257.84 clienteC1092: COLA COMERCIAL - llegue con un IA: 12.58
# Atendiendo:[c:60, e:20]
# En cola:[c:80, e:0]
# T=5263.55 clienteC1093: COLA COMERCIAL - llegue con un IA:  5.71
# Atendiendo:[c:60, e:20]
# En cola:[c:81, e:0]
# T=5281.62 clienteC1094: COLA COMERCIAL - llegue con un IA: 18.08
# Atendiendo:[c:60, e:20]
# En cola:[c:82, e:0]
# T=5310.96 clienteC1095: COLA COMERCIAL - llegue con un IA: 29.34
# Atendiendo:[c:60, e:20]
# En cola:[c:83, e:0]
# T=5335.22 clienteC1096: COLA COMERCIAL - llegue con un IA: 24.26
# Atendiendo:[c:60, e:20]
# En cola:[c:84, e:0]
# T=5352.74 clienteC1097: COLA COMERCIAL - llegue con un IA: 17.53
# Atendiendo:[c:60, e:20]
# En cola:[c:85, e:0]
# T=5400.52 clienteC1098: COLA COMERCIAL - llegue con un IA: 47.78
# Atendiendo:[c:60, e:20]
# En cola:[c:86, e:0]
# T=5437.67 clienteC1099: COLA COMERCIAL - llegue con un IA: 37.15
# Atendiendo:[c:60, e:20]
# En cola:[c:87, e:0]
# T=5490.73 clienteE1100: COLA EMERGENCIA - llegue con un IA: 53.06
# Atendiendo:[c:60, e:20]
# En cola:[c:88, e:0]
# T=5490.73, clienteE1100: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:21]
# En cola:[c:88, e:0]
# Tiempo de Atencion generado para clienteE1100: 573.15
# T=5527.69 clienteC1101: COLA COMERCIAL - llegue con un IA: 36.96
# Atendiendo:[c:60, e:21]
# En cola:[c:88, e:0]
# T=5551.49 clienteC1102: COLA COMERCIAL - llegue con un IA: 23.80
# Atendiendo:[c:60, e:21]
# En cola:[c:89, e:0]
# T=5600.41 clienteE1103: COLA EMERGENCIA - llegue con un IA: 48.92
# Atendiendo:[c:60, e:21]
# En cola:[c:90, e:0]
# T=5600.41, clienteE1103: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:22]
# En cola:[c:90, e:0]
# Tiempo de Atencion generado para clienteE1103: 186.38
# T=5607.17 clienteC1104: COLA COMERCIAL - llegue con un IA:  6.76
# Atendiendo:[c:60, e:22]
# En cola:[c:90, e:0]
# T=5629.55 clienteC1105: COLA COMERCIAL - llegue con un IA: 22.38
# Atendiendo:[c:60, e:22]
# En cola:[c:91, e:0]
# T=5683.83 clienteC1106: COLA COMERCIAL - llegue con un IA: 54.28
# Atendiendo:[c:60, e:22]
# En cola:[c:92, e:0]
# T=5695.66 clienteE1107: COLA EMERGENCIA - llegue con un IA: 11.83
# Atendiendo:[c:60, e:22]
# En cola:[c:93, e:0]
# T=5695.66, clienteE1107: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:23]
# En cola:[c:93, e:0]
# Tiempo de Atencion generado para clienteE1107: 330.26
# T=5741.53 clienteC1108: COLA COMERCIAL - llegue con un IA: 45.87
# Atendiendo:[c:60, e:23]
# En cola:[c:93, e:0]
# T=5785.63 clienteC1109: COLA COMERCIAL - llegue con un IA: 44.10
# Atendiendo:[c:60, e:23]
# En cola:[c:94, e:0]
# T=5786.79, clienteE1103: Sali de un puesto de emergencia
# T=5803.58 clienteC1110: COLA COMERCIAL - llegue con un IA: 17.96
# Atendiendo:[c:60, e:23]
# En cola:[c:95, e:0]
# T=5834.45 clienteC1111: COLA COMERCIAL - llegue con un IA: 30.87
# Atendiendo:[c:60, e:23]
# En cola:[c:96, e:0]
# T=5851.10 clienteE1112: COLA EMERGENCIA - llegue con un IA: 16.65
# Atendiendo:[c:60, e:23]
# En cola:[c:97, e:0]
# T=5851.10, clienteE1112: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:24]
# En cola:[c:97, e:0]
# Tiempo de Atencion generado para clienteE1112: 76.87
# T=5862.47 clienteC1113: COLA COMERCIAL - llegue con un IA: 11.37
# Atendiendo:[c:60, e:24]
# En cola:[c:97, e:0]
# T=5871.58 clienteC1114: COLA COMERCIAL - llegue con un IA:  9.11
# Atendiendo:[c:60, e:24]
# En cola:[c:98, e:0]
# T=5886.75 clienteC1115: COLA COMERCIAL - llegue con un IA: 15.17
# Atendiendo:[c:60, e:24]
# En cola:[c:99, e:0]
# T=5924.00 clienteC1116: COLA COMERCIAL - llegue con un IA: 37.25
# Atendiendo:[c:60, e:24]
# En cola:[c:100, e:0]
# T=5927.97, clienteE1112: Sali de un puesto de emergencia
# T=5979.65 clienteC1117: COLA COMERCIAL - llegue con un IA: 55.65
# Atendiendo:[c:60, e:24]
# En cola:[c:101, e:0]
# T=6014.09 clienteE1118: COLA EMERGENCIA - llegue con un IA: 34.44
# Atendiendo:[c:60, e:24]
# En cola:[c:102, e:0]
# T=6014.09, clienteE1118: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:25]
# En cola:[c:102, e:0]
# Tiempo de Atencion generado para clienteE1118: 139.81
# T=6025.92, clienteE1107: Sali de un puesto de emergencia
# T=6026.81 clienteC1119: COLA COMERCIAL - llegue con un IA: 12.72
# Atendiendo:[c:60, e:25]
# En cola:[c:102, e:0]
# T=6052.77 clienteE1120: COLA EMERGENCIA - llegue con un IA: 25.96
# Atendiendo:[c:60, e:25]
# En cola:[c:103, e:0]
# T=6052.77, clienteE1120: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:26]
# En cola:[c:103, e:0]
# Tiempo de Atencion generado para clienteE1120: 475.44
# T=6063.87, clienteE1100: Sali de un puesto de emergencia
# T=6082.28 clienteC1121: COLA COMERCIAL - llegue con un IA: 29.51
# Atendiendo:[c:60, e:26]
# En cola:[c:103, e:0]
# T=6084.57 clienteC1122: COLA COMERCIAL - llegue con un IA:  2.29
# Atendiendo:[c:60, e:26]
# En cola:[c:104, e:0]
# T=6112.42 clienteC1123: COLA COMERCIAL - llegue con un IA: 27.85
# Atendiendo:[c:60, e:26]
# En cola:[c:105, e:0]
# T=6125.89 clienteC1124: COLA COMERCIAL - llegue con un IA: 13.47
# Atendiendo:[c:60, e:26]
# En cola:[c:106, e:0]
# T=6153.90, clienteE1118: Sali de un puesto de emergencia
# T=6161.34 clienteC1125: COLA COMERCIAL - llegue con un IA: 35.45
# Atendiendo:[c:60, e:26]
# En cola:[c:107, e:0]
# T=6186.98 clienteC1126: COLA COMERCIAL - llegue con un IA: 25.64
# Atendiendo:[c:60, e:26]
# En cola:[c:108, e:0]
# T=6212.68 clienteC1127: COLA COMERCIAL - llegue con un IA: 25.71
# Atendiendo:[c:60, e:26]
# En cola:[c:109, e:0]
# T=6237.36 clienteE1128: COLA EMERGENCIA - llegue con un IA: 24.67
# Atendiendo:[c:60, e:26]
# En cola:[c:110, e:0]
# T=6237.36, clienteE1128: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:27]
# En cola:[c:110, e:0]
# Tiempo de Atencion generado para clienteE1128: 102.91
# T=6293.40 clienteC1129: COLA COMERCIAL - llegue con un IA: 56.05
# Atendiendo:[c:60, e:27]
# En cola:[c:110, e:0]
# T=6321.24 clienteC1130: COLA COMERCIAL - llegue con un IA: 27.84
# Atendiendo:[c:60, e:27]
# En cola:[c:111, e:0]
# T=6340.27, clienteE1128: Sali de un puesto de emergencia
# T=6354.26 clienteC1131: COLA COMERCIAL - llegue con un IA: 33.02
# Atendiendo:[c:60, e:27]
# En cola:[c:112, e:0]
# T=6368.09 clienteC1132: COLA COMERCIAL - llegue con un IA: 13.83
# Atendiendo:[c:60, e:27]
# En cola:[c:113, e:0]
# T=6415.59 clienteC1133: COLA COMERCIAL - llegue con un IA: 47.50
# Atendiendo:[c:60, e:27]
# En cola:[c:114, e:0]
# T=6452.71 clienteC1134: COLA COMERCIAL - llegue con un IA: 37.12
# Atendiendo:[c:60, e:27]
# En cola:[c:115, e:0]
# T=6455.39 clienteC1135: COLA COMERCIAL - llegue con un IA:  2.68
# Atendiendo:[c:60, e:27]
# En cola:[c:116, e:0]
# T=6481.45 clienteC1136: COLA COMERCIAL - llegue con un IA: 26.06
# Atendiendo:[c:60, e:27]
# En cola:[c:117, e:0]
# T=6483.20 clienteC1137: COLA COMERCIAL - llegue con un IA:  1.75
# ...
# En cola:[c:243, e:0]
# T=10659.64 clienteC1278: COLA COMERCIAL - llegue con un IA: 15.01
# Atendiendo:[c:60, e:42]
# En cola:[c:244, e:0]
# T=10675.41 clienteE1279: COLA EMERGENCIA - llegue con un IA: 15.77
# Atendiendo:[c:60, e:42]
# En cola:[c:245, e:0]
# T=10675.41, clienteE1279: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:43]
# En cola:[c:245, e:0]
# Tiempo de Atencion generado para clienteE1279: 268.92
# T=10702.73 clienteC1280: COLA COMERCIAL - llegue con un IA: 27.32
# Atendiendo:[c:60, e:43]
# En cola:[c:245, e:0]
# T=10752.99 clienteC1281: COLA COMERCIAL - llegue con un IA: 50.26
# Atendiendo:[c:60, e:43]
# En cola:[c:246, e:0]
# T=10793.00 clienteC1282: COLA COMERCIAL - llegue con un IA: 40.01
# Atendiendo:[c:60, e:43]
# En cola:[c:247, e:0]
# T=10825.13 clienteE1283: COLA EMERGENCIA - llegue con un IA: 32.13
# Atendiendo:[c:60, e:43]
# En cola:[c:248, e:0]
# T=10825.13, clienteE1283: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:44]
# En cola:[c:248, e:0]
# Tiempo de Atencion generado para clienteE1283: 345.87
# T=10830.70 clienteC1284: COLA COMERCIAL - llegue con un IA:  5.58
# Atendiendo:[c:60, e:44]
# En cola:[c:248, e:0]
# T=10876.59 clienteC1285: COLA COMERCIAL - llegue con un IA: 45.89
# Atendiendo:[c:60, e:44]
# En cola:[c:249, e:0]
# T=10896.68 clienteC1286: COLA COMERCIAL - llegue con un IA: 20.09
# Atendiendo:[c:60, e:44]
# En cola:[c:250, e:0]
# T=10906.42 clienteC1287: COLA COMERCIAL - llegue con un IA:  9.74
# Atendiendo:[c:60, e:44]
# En cola:[c:251, e:0]
# T=10944.33, clienteE1279: Sali de un puesto de emergencia
# T=10949.68 clienteC1288: COLA COMERCIAL - llegue con un IA: 43.26
# Atendiendo:[c:60, e:44]
# En cola:[c:252, e:0]
# T=11000.99 clienteC1289: COLA COMERCIAL - llegue con un IA: 51.31
# Atendiendo:[c:60, e:44]
# En cola:[c:253, e:0]
# T=11010.72 clienteC1290: COLA COMERCIAL - llegue con un IA:  9.73
# Atendiendo:[c:60, e:44]
# En cola:[c:254, e:0]
# T=11070.35 clienteE1291: COLA EMERGENCIA - llegue con un IA: 59.63
# Atendiendo:[c:60, e:44]
# En cola:[c:255, e:0]
# T=11070.35, clienteE1291: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:45]
# En cola:[c:255, e:0]
# Tiempo de Atencion generado para clienteE1291: 145.99
# T=11072.02, clienteE1275: Sali de un puesto de emergencia
# T=11103.68 clienteC1292: COLA COMERCIAL - llegue con un IA: 33.33
# Atendiendo:[c:60, e:45]
# En cola:[c:255, e:0]
# T=11125.17 clienteC1293: COLA COMERCIAL - llegue con un IA: 21.48
# Atendiendo:[c:60, e:45]
# En cola:[c:256, e:0]
# T=11146.14 clienteC1294: COLA COMERCIAL - llegue con un IA: 20.97
# Atendiendo:[c:60, e:45]
# En cola:[c:257, e:0]
# T=11149.54 clienteE1295: COLA EMERGENCIA - llegue con un IA:  3.41
# Atendiendo:[c:60, e:45]
# En cola:[c:258, e:0]
# T=11149.54, clienteE1295: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:46]
# En cola:[c:258, e:0]
# Tiempo de Atencion generado para clienteE1295: 22.82
# T=11165.41 clienteC1296: COLA COMERCIAL - llegue con un IA: 15.87
# Atendiendo:[c:60, e:46]
# En cola:[c:258, e:0]
# T=11171.00, clienteE1283: Sali de un puesto de emergencia
# T=11172.37, clienteE1295: Sali de un puesto de emergencia
# T=11185.39 clienteC1297: COLA COMERCIAL - llegue con un IA: 19.98
# Atendiendo:[c:60, e:46]
# En cola:[c:259, e:0]
# T=11205.62 clienteC1298: COLA COMERCIAL - llegue con un IA: 20.23
# Atendiendo:[c:60, e:46]
# En cola:[c:260, e:0]
# T=11216.34, clienteE1291: Sali de un puesto de emergencia
# T=11232.13 clienteC1299: COLA COMERCIAL - llegue con un IA: 26.51
# Atendiendo:[c:60, e:46]
# En cola:[c:261, e:0]
# T=11271.28 clienteC1300: COLA COMERCIAL - llegue con un IA: 39.14
# Atendiendo:[c:60, e:46]
# En cola:[c:262, e:0]
# T=11290.83 clienteC1301: COLA COMERCIAL - llegue con un IA: 19.55
# Atendiendo:[c:60, e:46]
# En cola:[c:263, e:0]
# T=11291.85 clienteC1302: COLA COMERCIAL - llegue con un IA:  1.02
# Atendiendo:[c:60, e:46]
# En cola:[c:264, e:0]
# T=11309.20 clienteC1303: COLA COMERCIAL - llegue con un IA: 17.36
# Atendiendo:[c:60, e:46]
# En cola:[c:265, e:0]
# T=11322.82 clienteE1304: COLA EMERGENCIA - llegue con un IA: 13.62
# Atendiendo:[c:60, e:46]
# En cola:[c:266, e:0]
# T=11322.82, clienteE1304: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:47]
# En cola:[c:266, e:0]
# Tiempo de Atencion generado para clienteE1304: 109.04
# T=11378.32 clienteC1305: COLA COMERCIAL - llegue con un IA: 55.49
# Atendiendo:[c:60, e:47]
# En cola:[c:266, e:0]
# T=11396.22 clienteC1306: COLA COMERCIAL - llegue con un IA: 17.91
# Atendiendo:[c:60, e:47]
# En cola:[c:267, e:0]
# T=11416.92 clienteC1307: COLA COMERCIAL - llegue con un IA: 20.70
# Atendiendo:[c:60, e:47]
# En cola:[c:268, e:0]
# T=11431.86, clienteE1304: Sali de un puesto de emergencia
# T=11475.69 clienteE1308: COLA EMERGENCIA - llegue con un IA: 58.77
# Atendiendo:[c:60, e:47]
# En cola:[c:269, e:0]
# T=11475.69, clienteE1308: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:48]
# En cola:[c:269, e:0]
# Tiempo de Atencion generado para clienteE1308: 186.80
# T=11535.52 clienteC1309: COLA COMERCIAL - llegue con un IA: 59.82
# Atendiendo:[c:60, e:48]
# En cola:[c:269, e:0]
# T=11593.77 clienteC1310: COLA COMERCIAL - llegue con un IA: 58.26
# Atendiendo:[c:60, e:48]
# En cola:[c:270, e:0]
# T=11627.49 clienteC1311: COLA COMERCIAL - llegue con un IA: 33.72
# Atendiendo:[c:60, e:48]
# En cola:[c:271, e:0]
# T=11662.49, clienteE1308: Sali de un puesto de emergencia
# T=11673.28 clienteE1312: COLA EMERGENCIA - llegue con un IA: 45.79
# Atendiendo:[c:60, e:48]
# En cola:[c:272, e:0]
# T=11673.28, clienteE1312: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:49]
# En cola:[c:272, e:0]
# Tiempo de Atencion generado para clienteE1312: 416.66
# T=11716.89 clienteE1313: COLA EMERGENCIA - llegue con un IA: 43.61
# Atendiendo:[c:60, e:49]
# En cola:[c:272, e:0]
# T=11716.89, clienteE1313: COLA EMERGENCIA - Me atendieron en un puesto de emergencia despues de esperar  0.00
# Atendiendo:[c:60, e:50]
# En cola:[c:272, e:0]
# Tiempo de Atencion generado para clienteE1313: 375.77
# T=11722.35 clienteC1314: COLA COMERCIAL - llegue con un IA:  5.46
# Atendiendo:[c:60, e:50]
# En cola:[c:272, e:0]
# T=11732.76 clienteC1315: COLA COMERCIAL - llegue con un IA: 10.41
# Atendiendo:[c:60, e:50]
# En cola:[c:273, e:0]
# T=11752.44 clienteC1316: COLA COMERCIAL - llegue con un IA: 19.69
# Atendiendo:[c:60, e:50]
# En cola:[c:274, e:0]
# T=11769.35 clienteC1317: COLA COMERCIAL - llegue con un IA: 16.91
# Atendiendo:[c:60, e:50]
# En cola:[c:275, e:0]
# T=11813.64 clienteC1318: COLA COMERCIAL - llegue con un IA: 44.29
# Atendiendo:[c:60, e:50]
# En cola:[c:276, e:0]
# T=11866.25 clienteC1319: COLA COMERCIAL - llegue con un IA: 52.61
# Atendiendo:[c:60, e:50]
# En cola:[c:277, e:0]
# T=11868.40 clienteC1320: COLA COMERCIAL - llegue con un IA:  2.16
# Atendiendo:[c:60, e:50]
# En cola:[c:278, e:0]
# T=11918.91 clienteC1321: COLA COMERCIAL - llegue con un IA: 50.51
# Atendiendo:[c:60, e:50]
# En cola:[c:279, e:0]
# T=11938.99 clienteE1322: COLA EMERGENCIA - llegue con un IA: 20.08
# Atendiendo:[c:60, e:50]
# En cola:[c:280, e:0]
# T=11983.76 clienteC1323: COLA COMERCIAL - llegue con un IA: 44.77
# Atendiendo:[c:60, e:50]
# En cola:[c:280, e:1]
# T=12001.84 clienteC1324: COLA COMERCIAL - llegue con un IA: 18.08
# Atendiendo:[c:60, e:50]
# En cola:[c:281, e:1]
# T=12007.78 clienteE1325: COLA EMERGENCIA - llegue con un IA:  5.94
# Atendiendo:[c:60, e:50]
# En cola:[c:282, e:1]
# T=12021.30 clienteC1326: COLA COMERCIAL - llegue con un IA: 13.52
# Atendiendo:[c:60, e:50]
# En cola:[c:282, e:2]
# T=12052.00 clienteC1327: COLA COMERCIAL - llegue con un IA: 30.70
# Atendiendo:[c:60, e:50]
# En cola:[c:283, e:2]
# T=12089.94, clienteE1312: Sali de un puesto de emergencia
# T=12092.66, clienteE1313: Sali de un puesto de emergencia
# T=12109.39 clienteC1328: COLA COMERCIAL - llegue con un IA: 57.40
# Atendiendo:[c:60, e:50]
# En cola:[c:284, e:2]
# T=12141.46 clienteC1329: COLA COMERCIAL - llegue con un IA: 32.07
# Atendiendo:[c:60, e:50]
# En cola:[c:285, e:2]
# T=12158.63 clienteC1330: COLA COMERCIAL - llegue con un IA: 17.17
# Atendiendo:[c:60, e:50]
# En cola:[c:286, e:2]
# T=12191.31 clienteE1331: COLA EMERGENCIA - llegue con un IA: 32.67
# Atendiendo:[c:60, e:50]
# En cola:[c:287, e:2]
# T=12235.08 clienteC1332: COLA COMERCIAL - llegue con un IA: 43.77
# Atendiendo:[c:60, e:50]
# En cola:[c:287, e:3]
# T=12287.39 clienteC1333: COLA COMERCIAL - llegue con un IA: 52.31
# Atendiendo:[c:60, e:50]
# En cola:[c:288, e:3]
# T=12346.90 clienteC1334: COLA COMERCIAL - llegue con un IA: 59.52
# Atendiendo:[c:60, e:50]
# En cola:[c:289, e:3]
# T=12381.17 clienteC1335: COLA COMERCIAL - llegue con un IA: 34.27
# Atendiendo:[c:60, e:50]
# En cola:[c:290, e:3]
# T=12395.74 clienteC1336: COLA COMERCIAL - llegue con un IA: 14.57
# Atendiendo:[c:60, e:50]
# En cola:[c:291, e:3]
# T=12443.63 clienteC1337: COLA COMERCIAL - llegue con un IA: 47.89
# Atendiendo:[c:60, e:50]
# En cola:[c:292, e:3]
# T=12464.06 clienteC1338: COLA COMERCIAL - llegue con un IA: 20.43
# Atendiendo:[c:60, e:50]
# En cola:[c:293, e:3]
# T=12489.47 clienteC1339: COLA COMERCIAL - llegue con un IA: 25.40
# Atendiendo:[c:60, e:50]
# En cola:[c:294, e:3]
# T=12505.70 clienteC1340: COLA COMERCIAL - llegue con un IA: 16.24
# Atendiendo:[c:60, e:50]
# En cola:[c:295, e:3]
# T=12511.10 clienteC1341: COLA COMERCIAL - llegue con un IA:  5.40
# Atendiendo:[c:60, e:50]
# En cola:[c:296, e:3]
# T=12514.00 clienteC1342: COLA COMERCIAL - llegue con un IA:  2.90
# Atendiendo:[c:60, e:50]
# En cola:[c:297, e:3]
# T=12541.10 clienteC1343: COLA COMERCIAL - llegue con un IA: 27.10
# Atendiendo:[c:60, e:50]
# En cola:[c:298, e:3]
# T=12590.87 clienteC1344: COLA COMERCIAL - llegue con un IA: 49.76
# Atendiendo:[c:60, e:50]
# En cola:[c:299, e:3]
# T=12617.56 clienteC1345: COLA COMERCIAL - llegue con un IA: 26.69
# Atendiendo:[c:60, e:50]
# En cola:[c:300, e:3]
# T=12673.38 clienteC1346: COLA COMERCIAL - llegue con un IA: 55.82
# Atendiendo:[c:60, e:50]
# En cola:[c:301, e:3]
# T=12717.85 clienteE1347: COLA EMERGENCIA - llegue con un IA: 44.47
# Atendiendo:[c:60, e:50]
# En cola:[c:302, e:3]
# T=12741.55 clienteC1348: COLA COMERCIAL - llegue con un IA: 23.70
# Atendiendo:[c:60, e:50]
# En cola:[c:302, e:4]
# T=12752.64 clienteC1349: COLA COMERCIAL - llegue con un IA: 11.09
# Atendiendo:[c:60, e:50]
# En cola:[c:303, e:4]
# T=12787.54 clienteC1350: COLA COMERCIAL - llegue con un IA: 34.90
# Atendiendo:[c:60, e:50]
# En cola:[c:304, e:4]
# T=12824.90 clienteC1351: COLA COMERCIAL - llegue con un IA: 37.36
# Atendiendo:[c:60, e:50]
# En cola:[c:305, e:4]
# T=12856.24 clienteC1352: COLA COMERCIAL - llegue con un IA: 31.34
# Atendiendo:[c:60, e:50]
# En cola:[c:306, e:4]
# T=12863.43 clienteC1353: COLA COMERCIAL - llegue con un IA:  7.19
# Atendiendo:[c:60, e:50]
# En cola:[c:307, e:4]
# T=12884.92 clienteC1354: COLA COMERCIAL - llegue con un IA: 21.50
# Atendiendo:[c:60, e:50]
# En cola:[c:308, e:4]
# T=12904.61 clienteC1355: COLA COMERCIAL - llegue con un IA: 19.68
# Atendiendo:[c:60, e:50]
# En cola:[c:309, e:4]
# T=12950.63 clienteC1356: COLA COMERCIAL - llegue con un IA: 46.02
# Atendiendo:[c:60, e:50]
# En cola:[c:310, e:4]
# T=12984.26 clienteC1357: COLA COMERCIAL - llegue con un IA: 33.63
# Atendiendo:[c:60, e:50]
# En cola:[c:311, e:4]
# T=13005.55 clienteC1358: COLA COMERCIAL - llegue con un IA: 21.29
# Atendiendo:[c:60, e:50]
# En cola:[c:312, e:4]
# T=13063.24 clienteC1359: COLA COMERCIAL - llegue con un IA: 57.69
# Atendiendo:[c:60, e:50]
# En cola:[c:313, e:4]
# T=13069.68 clienteC1360: COLA COMERCIAL - llegue con un IA:  6.44
# Atendiendo:[c:60, e:50]
# En cola:[c:314, e:4]
# T=13094.17 clienteC1361: COLA COMERCIAL - llegue con un IA: 24.49
# Atendiendo:[c:60, e:50]
# En cola:[c:315, e:4]
# T=13116.81 clienteC1362: COLA COMERCIAL - llegue con un IA: 22.64
# Atendiendo:[c:60, e:50]
# En cola:[c:316, e:4]
# T=13141.48 clienteC1363: COLA COMERCIAL - llegue con un IA: 24.67
# Atendiendo:[c:60, e:50]
# En cola:[c:317, e:4]
# T=13176.16 clienteC1364: COLA COMERCIAL - llegue con un IA: 34.67
# Atendiendo:[c:60, e:50]
# En cola:[c:318, e:4]
# T=13231.24 clienteC1365: COLA COMERCIAL - llegue con un IA: 55.08
# Atendiendo:[c:60, e:50]
# En cola:[c:319, e:4]
# T=13272.08 clienteC1366: COLA COMERCIAL - llegue con un IA: 40.84
# Atendiendo:[c:60, e:50]
# En cola:[c:320, e:4]
# T=13279.78 clienteC1367: COLA COMERCIAL - llegue con un IA:  7.69
# Atendiendo:[c:60, e:50]
# En cola:[c:321, e:4]
# T=13306.39 clienteC1368: COLA COMERCIAL - llegue con un IA: 26.61
# Atendiendo:[c:60, e:50]
# En cola:[c:322, e:4]
# T=13310.46 clienteC1369: COLA COMERCIAL - llegue con un IA:  4.07
# Atendiendo:[c:60, e:50]
# En cola:[c:323, e:4]
# T=13343.25 clienteC1370: COLA COMERCIAL - llegue con un IA: 32.80
# Atendiendo:[c:60, e:50]
# En cola:[c:324, e:4]
# T=13378.50 clienteE1371: COLA EMERGENCIA - llegue con un IA: 35.25
# Atendiendo:[c:60, e:50]
# En cola:[c:325, e:4]
# T=13432.97 clienteC1372: COLA COMERCIAL - llegue con un IA: 54.47
# Atendiendo:[c:60, e:50]
# En cola:[c:325, e:5]
# T=13467.54 clienteE1373: COLA EMERGENCIA - llegue con un IA: 34.57
# Atendiendo:[c:60, e:50]
# En cola:[c:326, e:5]
# T=13502.34 clienteC1374: COLA COMERCIAL - llegue con un IA: 34.80
# Atendiendo:[c:60, e:50]
# En cola:[c:326, e:6]
# T=13528.18 clienteC1375: COLA COMERCIAL - llegue con un IA: 25.84
# Atendiendo:[c:60, e:50]
# En cola:[c:327, e:6]
# T=13583.26 clienteC1376: COLA COMERCIAL - llegue con un IA: 55.09
# Atendiendo:[c:60, e:50]
# En cola:[c:328, e:6]
# T=13626.29 clienteC1377: COLA COMERCIAL - llegue con un IA: 43.02
# Atendiendo:[c:60, e:50]
# En cola:[c:329, e:6]
# T=13679.24 clienteC1378: COLA COMERCIAL - llegue con un IA: 52.96
# Atendiendo:[c:60, e:50]
# En cola:[c:330, e:6]
# T=13716.74 clienteC1379: COLA COMERCIAL - llegue con un IA: 37.50
# Atendiendo:[c:60, e:50]
# En cola:[c:331, e:6]
# T=13718.20 clienteC1380: COLA COMERCIAL - llegue con un IA:  1.45
# Atendiendo:[c:60, e:50]
# En cola:[c:332, e:6]
# T=13735.28 clienteC1381: COLA COMERCIAL - llegue con un IA: 17.08
# Atendiendo:[c:60, e:50]
# En cola:[c:333, e:6]
# T=13789.77 clienteE1382: COLA EMERGENCIA - llegue con un IA: 54.49
# Atendiendo:[c:60, e:50]
# En cola:[c:334, e:6]
# T=13801.89 clienteC1383: COLA COMERCIAL - llegue con un IA: 12.12
# Atendiendo:[c:60, e:50]
# En cola:[c:334, e:7]
# T=13848.93 clienteC1384: COLA COMERCIAL - llegue con un IA: 47.04
# Atendiendo:[c:60, e:50]
# En cola:[c:335, e:7]
# T=13854.77 clienteC1385: COLA COMERCIAL - llegue con un IA:  5.84
# Atendiendo:[c:60, e:50]
# En cola:[c:336, e:7]
# T=13883.88 clienteC1386: COLA COMERCIAL - llegue con un IA: 29.11
# Atendiendo:[c:60, e:50]
# En cola:[c:337, e:7]
# T=13899.56 clienteC1387: COLA COMERCIAL - llegue con un IA: 15.67
# Atendiendo:[c:60, e:50]
# En cola:[c:338, e:7]
# T=13937.88 clienteC1388: COLA COMERCIAL - llegue con un IA: 38.32
# Atendiendo:[c:60, e:50]
# En cola:[c:339, e:7]
# T=13963.49 clienteC1389: COLA COMERCIAL - llegue con un IA: 25.61
# Atendiendo:[c:60, e:50]
# En cola:[c:340, e:7]
# T=13991.52 clienteC1390: COLA COMERCIAL - llegue con un IA: 28.03
# Atendiendo:[c:60, e:50]
# En cola:[c:341, e:7]
# T=14012.74 clienteC1391: COLA COMERCIAL - llegue con un IA: 21.22
# Atendiendo:[c:60, e:50]
# En cola:[c:342, e:7]
# T=14025.73 clienteC1392: COLA COMERCIAL - llegue con un IA: 12.99
# Atendiendo:[c:60, e:50]
# En cola:[c:343, e:7]
# T=14069.61 clienteE1393: COLA EMERGENCIA - llegue con un IA: 43.88
# Atendiendo:[c:60, e:50]
# En cola:[c:344, e:7]
# T=14129.22 clienteC1394: COLA COMERCIAL - llegue con un IA: 59.62
# Atendiendo:[c:60, e:50]
# En cola:[c:344, e:8]
# T=14188.14 clienteC1395: COLA COMERCIAL - llegue con un IA: 58.91
# Atendiendo:[c:60, e:50]
# En cola:[c:345, e:8]
# T=14214.50 clienteC1396: COLA COMERCIAL - llegue con un IA: 26.36
# Atendiendo:[c:60, e:50]
# En cola:[c:346, e:8]
# T=14255.96 clienteC1397: COLA COMERCIAL - llegue con un IA: 41.47
# Atendiendo:[c:60, e:50]
# En cola:[c:347, e:8]
# T=14281.79 clienteC1398: COLA COMERCIAL - llegue con un IA: 25.83
# Atendiendo:[c:60, e:50]
# En cola:[c:348, e:8]
# T=14327.01 clienteE1399: COLA EMERGENCIA - llegue con un IA: 45.22
# Atendiendo:[c:60, e:50]
# En cola:[c:349, e:8]
# T=14377.84 clienteC1400: COLA COMERCIAL - llegue con un IA: 50.82
# Atendiendo:[c:60, e:50]
# En cola:[c:349, e:9]
# T=14399.27 clienteC1401: COLA COMERCIAL - llegue con un IA: 21.43
# Atendiendo:[c:60, e:50]
# En cola:[c:350, e:9]

# %% [markdown]
# Results

# %%
print("===========================================================================")
print("RESULTADOS:")
print("Clientes totales: %1d"%ci["NT"])
print("Tiempo de espera en cola total: %1d"%ci["NEC"]) # Sacar esto despues
PEC = (ci["NEC"] / ci["NT"]) * 100
# Porcentaje de espera menor a 40 segundos
print("Porcentaje de espera en cola menor a 40 segundos: %5.2f"%PEC)
# Objetio: Mayor o igual al 90%

print('Cantidad de puestos comerciales',cantCom)
print('Cantidad de puestos de emergencia',cantEmer)
print('Cantidad de puestos polifuncionales',cantPolif)
print("Cantidad de gente atendido por polifuncional",ci["multitasking"])
# Out:
# ===========================================================================
# RESULTADOS:
# Clientes totales: 1402
# Tiempo de espera en cola total: 216
# Porcentaje de espera en cola menor a 40 segundos: 15.41
# Cantidad de puestos comerciales 60
# Cantidad de puestos de emergencia 50
# Cantidad de puestos polifuncionales 80
# Cantidad de gente atendido por polifuncional 140
